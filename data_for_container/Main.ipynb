# %%
from urllib.request import Request
from urllib.request import urlopen
from urllib import parse
from urllib.error import HTTPError
from pprint import pprint as pp
import json
import pandas as pd
import io

# %%
CONSUMER_KEY = "90517-93a71429963a2848be5451f9" # For Mac - https://getpocket.com/developer/apps/

ACCESS_TOKEN = "633a246a-35dd-e1e1-1fb6-c36df3"

request_url = "https://getpocket.com/v3/oauth/request"
get_url = "https://getpocket.com/v3/get"

# %%
def do_post_request(url, data):
    request = Request(url=url, data=data)
    try:
        http_response = urlopen(request)
    except HTTPError as e:
        print(e.headers.as_string())
    if http_response:
        text_response = http_response.read()
        return text_response

# %%
data = {
    'consumer_key': CONSUMER_KEY, 
    'redirect_uri': 'pocketapp1234:authorizationFinished'
}
obtain_request_token_response = do_post_request(request_url, parse.urlencode(data).encode())
code = obtain_request_token.decode("utf-8").split('code=')[1]
code
# Out:
# 'b6d9b6a2-289a-f2f9-9c0d-11c31c'

# %%
data = {
    'consumer_key': CONSUMER_KEY, 
    'access_token': ACCESS_TOKEN,
    'detailType': 'complete',
    'sort': 'newest'
}
all_tags_response = do_post_request(get_url, parse.urlencode(data).encode())
all_tags = json.loads(all_tags_response.decode('utf-8'))
tags_dict = all_tags['list']

# %%
tags_dict
# Out:
# {'698231177': {'item_id': '698231177',
#   'resolved_id': '698231177',
#   'given_url': 'https://fr.wikipedia.org/wiki/SHRDLU',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585673652',
#   'time_updated': '1585673660',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 0,
#   'resolved_title': 'SHRDLU',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/SHRDLU',
#   'excerpt': 'SHRDLU a été l’un des premiers programmes informatiques de compréhension du langage naturel, développé par Terry Winograd au MIT à partir de 1968-1970. Il était écrit en Micro Planner et en Lisp et implémenté sur un ordinateur PDP-6 de DEC équipé d’un terminal graphique DEC.',
#   'is_article': '1',
#   'is_index': '1',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '814',
#   'lang': 'fr',
#   'time_to_read': 4,
#   'top_image_url': 'https://upload.wikimedia.org/wikipedia/commons/b/bc/Shrdlu-original.jpg',
#   'tags': {'nlp': {'item_id': '698231177', 'tag': 'nlp'}},
#   'image': {'item_id': '698231177',
#    'src': 'https://fr.wikipedia.org/wiki/Fichier:Shrdlu-original.jpg',
#    'width': '220',
#    'height': '177'},
#   'images': {'1': {'item_id': '698231177',
#     'image_id': '1',
#     'src': 'https://fr.wikipedia.org/wiki/Fichier:Shrdlu-original.jpg',
#     'width': '220',
#     'height': '177',
#     'credit': '',
#     'caption': "Le logiciel présente un monde avec des blocs de différentes formes. L'utilisateur peut modifier le monde en donnant des instructions en langue naturelle."},
#    '2': {'item_id': '698231177',
#     'image_id': '2',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/02/Circle-icons-computer.svg/24px-Circle-icons-computer.svg.png',
#     'width': '24',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail de l’informatique'}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 315},
#  '12558068': {'item_id': '12558068',
#   'resolved_id': '12558068',
#   'given_url': 'https://fr.wikipedia.org/wiki/Th%C3%A9orie_algorithmique_de_l%27information',
#   'given_title': "Théorie algorithmique de l'information — Wikipédia",
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585670987',
#   'time_updated': '1585670997',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 1,
#   'resolved_title': "Théorie algorithmique de l'information",
#   'resolved_url': 'https://fr.wikipedia.org/wiki/Th%C3%A9orie_algorithmique_de_l%27information',
#   'excerpt': "La théorie algorithmique de l'information, initiée par Kolmogorov, Solomonov et Chaitin dans les années 1960, vise à quantifier et qualifier le contenu en information d'un ensemble de données, en utilisant la théorie de la calculabilité et la notion de machine universelle de Turing.",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '579',
#   'lang': 'fr',
#   'time_to_read': 3,
#   'tags': {'théories': {'item_id': '12558068', 'tag': 'théories'}},
#   'authors': {'3359036': {'item_id': '12558068',
#     'author_id': '3359036',
#     'name': 'biologie',
#     'url': 'https://fr.wikipedia.org/wiki/Biologie'}},
#   'image': {'item_id': '12558068',
#    'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Max-cut.svg/30px-Max-cut.svg.png',
#    'width': '30',
#    'height': '24'},
#   'images': {'1': {'item_id': '12558068',
#     'image_id': '1',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Max-cut.svg/30px-Max-cut.svg.png',
#     'width': '30',
#     'height': '24',
#     'credit': '',
#     'caption': "Portail de l'informatique théorique"}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 224},
#  '2448904635': {'item_id': '2448904635',
#   'resolved_id': '2448904635',
#   'given_url': 'https://stackoverflow.com/questions/50236117/scraping-ssl-certificate-verify-failed-error-for-http-en-wikipedia-org',
#   'given_title': 'python - Scraping: SSL: CERTIFICATE_VERIFY_FAILED error for http://en.wikip',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585646877',
#   'time_updated': '1585646885',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 2,
#   'resolved_title': 'Scraping: SSL: CERTIFICATE_VERIFY_FAILED error for http://en.wikipedia.org',
#   'resolved_url': 'https://stackoverflow.com/questions/50236117/scraping-ssl-certificate-verify-failed-error-for-http-en-wikipedia-org',
#   'excerpt': "Btw,I was also practicing scrapy, but kept getting the problem: command not found: scrapy (I tried all sorts of solutions online but none works... really frustrating) Once upon a time I stumbled with this issue. If you're using macOS go to Macintosh HD > Applications > Python3.",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '634',
#   'lang': 'en',
#   'time_to_read': 3,
#   'top_image_url': 'https://cdn.sstatic.net/Sites/stackoverflow/img/apple-touch-icon@2.png?v=73d79a89bded',
#   'tags': {'ssl: certificate_verify_f': {'item_id': '2448904635',
#     'tag': 'ssl: certificate_verify_f'},
#    'urlib': {'item_id': '2448904635', 'tag': 'urlib'}},
#   'authors': {'37243038': {'item_id': '2448904635',
#     'author_id': '37243038',
#     'name': 'smci',
#     'url': 'https://stackoverflow.com/users/202229/smci'},
#    '103000012': {'item_id': '2448904635',
#     'author_id': '103000012',
#     'name': 'Catherine4j',
#     'url': 'https://stackoverflow.com/users/9759042/catherine4j'}},
#   'image': {'item_id': '2448904635',
#    'src': 'https://graph.facebook.com/615748615301068/picture?type=large',
#    'width': '32',
#    'height': '32'},
#   'images': {'1': {'item_id': '2448904635',
#     'image_id': '1',
#     'src': 'https://graph.facebook.com/615748615301068/picture?type=large',
#     'width': '32',
#     'height': '32',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '2448904635',
#     'image_id': '2',
#     'src': 'https://i.stack.imgur.com/uUU4m.jpg?s=32&g=1',
#     'width': '32',
#     'height': '32',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '2448904635',
#     'image_id': '3',
#     'src': 'https://graph.facebook.com/1437199476299721/picture?type=large',
#     'width': '32',
#     'height': '32',
#     'credit': '',
#     'caption': ''}},
#   'domain_metadata': {'name': 'Stack Overflow',
#    'logo': 'https://logo.clearbit.com/stackoverflow.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/stackoverflow.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 245},
#  '2931905469': {'item_id': '2931905469',
#   'resolved_id': '2931905469',
#   'given_url': 'https://towardsdatascience.com/15-python-libraries-that-a-data-scientist-need-to-know-df0b3029ecd9',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585570363',
#   'time_updated': '1585672491',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 3,
#   'resolved_title': '15 Python Libraries That A Data Scientist Need To Know',
#   'resolved_url': 'https://towardsdatascience.com/15-python-libraries-that-a-data-scientist-need-to-know-df0b3029ecd9',
#   'excerpt': 'If you are a Data Scientist, Data Analyst or just an enthusiast, you should not miss some extremely popular and useful libraries for Python. In this article, totally 15 Python libraries will be listed and briefly introduced.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '2053',
#   'lang': 'en',
#   'time_to_read': 9,
#   'top_image_url': 'https://miro.medium.com/max/1200/1*A4sZ2qS0jxVmeA3qGba0ag.jpeg',
#   'tags': {'data science': {'item_id': '2931905469', 'tag': 'data science'}},
#   'authors': {'128552945': {'item_id': '2931905469',
#     'author_id': '128552945',
#     'name': 'Christopher Tao',
#     'url': 'https://towardsdatascience.com/@qiuyujx'}},
#   'image': {'item_id': '2931905469',
#    'src': 'https://miro.medium.com/max/3840/1*H4zCeuFMabhJfegvAw6UGg.jpeg',
#    'width': '1920',
#    'height': '728'},
#   'images': {'1': {'item_id': '2931905469',
#     'image_id': '1',
#     'src': 'https://miro.medium.com/max/3840/1*H4zCeuFMabhJfegvAw6UGg.jpeg',
#     'width': '1920',
#     'height': '728',
#     'credit': 'Pexels on Pixabay',
#     'caption': ''},
#    '2': {'item_id': '2931905469',
#     'image_id': '2',
#     'src': 'https://miro.medium.com/fit/c/96/96/1*aL2isee1E3zr8mzSXRiASA.png',
#     'width': '48',
#     'height': '48',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '2931905469',
#     'image_id': '3',
#     'src': 'https://miro.medium.com/max/3840/1*Lf64_S5ZAHrr9EvKJNcN7Q.jpeg',
#     'width': '1920',
#     'height': '1080',
#     'credit': 'geralt on Pixabay',
#     'caption': ''},
#    '4': {'item_id': '2931905469',
#     'image_id': '4',
#     'src': 'https://miro.medium.com/max/3840/1*RsLC2ruXUKt-rSF_BtCsog.jpeg',
#     'width': '1920',
#     'height': '1271',
#     'credit': 'Sztrapacska74 on Pixabay',
#     'caption': ''},
#    '5': {'item_id': '2931905469',
#     'image_id': '5',
#     'src': 'https://miro.medium.com/max/3840/1*A4sZ2qS0jxVmeA3qGba0ag.jpeg',
#     'width': '1920',
#     'height': '1271',
#     'credit': '6689062 on Pixabay',
#     'caption': ''},
#    '6': {'item_id': '2931905469',
#     'image_id': '6',
#     'src': 'https://miro.medium.com/max/3840/1*BL2DLU5dRn8OpLnXN7iU3A.jpeg',
#     'width': '1920',
#     'height': '1280',
#     'credit': 'FeeLoona on Pixabay',
#     'caption': ''},
#    '7': {'item_id': '2931905469',
#     'image_id': '7',
#     'src': 'https://miro.medium.com/max/3840/1*u6mk-djp_nE722Ap7zi1vg.jpeg',
#     'width': '1920',
#     'height': '1080',
#     'credit': 'Pexels on Pixabay',
#     'caption': ''},
#    '8': {'item_id': '2931905469',
#     'image_id': '8',
#     'src': 'https://miro.medium.com/max/2560/1*s_f1PwQw0pE3u0olLE-sWw.png',
#     'width': '1280',
#     'height': '1012',
#     'credit': '200degrees on Pixabay',
#     'caption': ''},
#    '9': {'item_id': '2931905469',
#     'image_id': '9',
#     'src': 'https://miro.medium.com/max/6000/0*w1iPf1hmDWwRnNuz',
#     'width': '3000',
#     'height': '2000',
#     'credit': 'Kelly Sikkema on Unsplash',
#     'caption': ''}},
#   'domain_metadata': {'name': 'Towards Data Science',
#    'logo': 'https://logo.clearbit.com/towardsdatascience.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/towardsdatascience.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 795},
#  '443041106': {'item_id': '443041106',
#   'resolved_id': '443041106',
#   'given_url': 'https://fr.wikipedia.org/wiki/Dalvik_(machine_virtuelle)',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585152989',
#   'time_updated': '1585152990',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 4,
#   'resolved_title': 'Dalvik (machine virtuelle)',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/Dalvik_(machine_virtuelle)',
#   'excerpt': "Dalvik est une machine virtuelle destinée aux téléphones mobiles et tablettes tactiles, qui est incorporée dans le système d'exploitation Android[1],[2].",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '692',
#   'lang': 'fr',
#   'time_to_read': 3,
#   'image': {'item_id': '443041106',
#    'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/02/Circle-icons-computer.svg/24px-Circle-icons-computer.svg.png',
#    'width': '24',
#    'height': '24'},
#   'images': {'1': {'item_id': '443041106',
#     'image_id': '1',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/02/Circle-icons-computer.svg/24px-Circle-icons-computer.svg.png',
#     'width': '24',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail de l’informatique'},
#    '2': {'item_id': '443041106',
#     'image_id': '2',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/03/Crystal_Clear_app_kpackage.png/24px-Crystal_Clear_app_kpackage.png',
#     'width': '24',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail du logiciel'}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 268},
#  '2927649046': {'item_id': '2927649046',
#   'resolved_id': '2927649046',
#   'given_url': 'https://www.google.com/search?q=nombre+mixte&rlz=1C9BKJA_enFR840FR840&oq=nombre+mixte&aqs=chrome..69i57.4206j0j4&hl=fr&sourceid=chrome-mobile&ie=UTF-8',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585151923',
#   'time_updated': '1585151980',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 5,
#   'resolved_title': 'nombre mixte',
#   'resolved_url': 'https://www.google.com/search?q=nombre+mixte&rlz=1C9BKJA_enFR840FR840&oq=nombre+mixte&aqs=chrome..69i57.4206j0j4&hl=fr&sourceid=chrome-mobile&ie=UTF-8',
#   'excerpt': "5 mai 2017 · Dans cette série de vidéos, les enfants découvriront les nombres mixtes. IL s'agit d'une manière ...",
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '19',
#   'lang': 'fr',
#   'tags': {'quizup': {'item_id': '2927649046', 'tag': 'quizup'}},
#   'domain_metadata': {'name': 'Google',
#    'logo': 'https://logo.clearbit.com/google.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/google.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 7},
#  '2927648143': {'item_id': '2927648143',
#   'resolved_id': '2927648143',
#   'given_url': 'https://fr.wikipedia.org/wiki/GX-4000',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585151867',
#   'time_updated': '1585151900',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 6,
#   'resolved_title': 'GX-4000',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/GX-4000',
#   'excerpt': "La GX-4000 est une console de jeux vidéo 8 bits d'Amstrad mise en vente en 1990. Elle est construite sur une base d'Amstrad CPC Plus et partage donc les mêmes caractéristiques que celui-ci. En 1989, les CPC se retrouvent complètement dépassés par les nouvelles machines 16 bits.",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '667',
#   'lang': 'fr',
#   'time_to_read': 3,
#   'top_image_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Amstrad-GX4000-Console-Set.png/1200px-Amstrad-GX4000-Console-Set.png',
#   'tags': {'quizup': {'item_id': '2927648143', 'tag': 'quizup'}},
#   'image': {'item_id': '2927648143',
#    'src': 'https://fr.wikipedia.org/wiki/Fichier:Amstrad-GX4000-Console-Set.png',
#    'width': '280',
#    'height': '116'},
#   'images': {'1': {'item_id': '2927648143',
#     'image_id': '1',
#     'src': 'https://fr.wikipedia.org/wiki/Fichier:Amstrad-GX4000-Console-Set.png',
#     'width': '280',
#     'height': '116',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '2927648143',
#     'image_id': '2',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/05/Crystal_Clear_app_package_games.png/24px-Crystal_Clear_app_package_games.png',
#     'width': '24',
#     'height': '24',
#     'credit': '',
#     'caption': ''}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 258},
#  '2927298340': {'item_id': '2927298340',
#   'resolved_id': '2927298340',
#   'given_url': 'https://blog.transloc.com/blog/what-is-gtfs-why-does-it-matter-public-transit',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585127858',
#   'time_updated': '1585127887',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 7,
#   'resolved_title': 'GTFS – What is it and why does it matter to public transit?',
#   'resolved_url': 'https://blog.transloc.com/blog/what-is-gtfs-why-does-it-matter-public-transit',
#   'excerpt': 'In my first few weeks of working at TransLoc, I frequently heard the term “GTFS feeds” passed around. Even after I was given a run-down of what it meant, I didn’t have a firm grasp of what GTFS feeds were and why they were actually important to transit agencies.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '1',
#   'has_image': '1',
#   'word_count': '764',
#   'lang': 'en',
#   'time_to_read': 3,
#   'amp_url': 'https://blog.transloc.com/blog/what-is-gtfs-why-does-it-matter-public-transit?hs_amp=true',
#   'top_image_url': 'https://blog.transloc.com/hubfs/GTFS%20post%20title_600x200@2x.png#keepProtocol',
#   'tags': {'google': {'item_id': '2927298340', 'tag': 'google'},
#    'tech': {'item_id': '2927298340', 'tag': 'tech'}},
#   'authors': {'81717026': {'item_id': '2927298340',
#     'author_id': '81717026',
#     'name': 'TransLoc Marketing',
#     'url': ''}},
#   'image': {'item_id': '2927298340',
#    'src': 'http://img.youtube.com/vi/NYkuBJTlOls/0.jpg',
#    'width': '480',
#    'height': '360'},
#   'images': {'1': {'item_id': '2927298340',
#     'image_id': '1',
#     'src': 'http://img.youtube.com/vi/NYkuBJTlOls/0.jpg',
#     'width': '480',
#     'height': '360',
#     'credit': '',
#     'caption': ''}},
#   'videos': {'1': {'item_id': '2927298340',
#     'video_id': '1',
#     'src': 'https://www.youtube.com/embed/NYkuBJTlOls?wmode=transparent',
#     'width': '560',
#     'height': '315',
#     'type': '1',
#     'vid': 'NYkuBJTlOls',
#     'length': '0'}},
#   'listen_duration_estimate': 296},
#  '2926302281': {'item_id': '2926302281',
#   'resolved_id': '2926302281',
#   'given_url': 'https://fr.appewa.com/reader/bb12496e-ebdf-4045-8fad-a3959d0353c7/article',
#   'given_title': "Apprendre l'Anglais en ligne - Écouter et parler avec EWA",
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585051993',
#   'time_updated': '1585067824',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 8,
#   'resolved_title': "Apprendre l'anglais en ligne",
#   'resolved_url': 'https://fr.appewa.com/reader/bb12496e-ebdf-4045-8fad-a3959d0353c7/article',
#   'excerpt': "Apprendre l'anglais en ligne",
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '4',
#   'lang': 'fr',
#   'listen_duration_estimate': 2},
#  '2907070551': {'item_id': '2907070551',
#   'resolved_id': '0',
#   'given_url': 'http://www.public.asu.edu/~hnesse/classes/seir.html',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1584877059',
#   'time_updated': '1584877071',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 9,
#   'resolved_title': '',
#   'resolved_url': '',
#   'excerpt': '',
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '0',
#   'lang': '',
#   'tags': {'corona': {'item_id': '2907070551', 'tag': 'corona'}},
#   'listen_duration_estimate': 0},
#  '2904803751': {'item_id': '2904803751',
#   'resolved_id': '2904803751',
#   'given_url': 'https://www.google.com/search?sxsrf=ALeKk03eeW7ZJNfvGrM6uMfFI7ukBNIBtA:1583257365212&q=les+freres+asniere+sur+seine&spell=1&sa=X&ved=2ahUKEwirrd2m7f7nAhVwD2MBHdqVBpcQBSgAegQIDBAq&biw=1440&bih=820&dpr=2',
#   'given_title': 'les freres asniere sur seine - Recherche Google',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1583336418',
#   'time_updated': '1583336421',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 10,
#   'resolved_title': 'les freres asniere sur seine',
#   'resolved_url': 'https://www.google.com/search?sxsrf=ALeKk03eeW7ZJNfvGrM6uMfFI7ukBNIBtA:1583257365212&q=les+freres+asniere+sur+seine&spell=1&sa=X&ved=2ahUKEwirrd2m7f7nAhVwD2MBHdqVBpcQBSgAegQIDBAq&biw=1440&bih=820&dpr=2',
#   'excerpt': "Association Quartier des 3 Frères à Asnières sur Seine, Asnières, Ile-De-France, France. 180 J'aime. Nous sommes l'Association qui regroupe les habitants...",
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '19',
#   'lang': 'en',
#   'domain_metadata': {'name': 'Google',
#    'logo': 'https://logo.clearbit.com/google.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/google.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 7},
#  '890289939': {'item_id': '890289939',
#   'resolved_id': '890289939',
#   'given_url': 'https://cloudinary.com/documentation/django_integration',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577899037',
#   'time_updated': '1577899049',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 11,
#   'resolved_title': 'Django integration',
#   'resolved_url': 'http://cloudinary.com/documentation/django_integration',
#   'excerpt': 'Cloudinary is a cloud-based service that provides an end-to-end image management solution including uploads, storage, manipulations, optimizations and delivery.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '1191',
#   'lang': 'en',
#   'time_to_read': 5,
#   'tags': {'django': {'item_id': '890289939', 'tag': 'django'}},
#   'image': {'item_id': '890289939',
#    'src': 'http://res.cloudinary.com/demo/image/upload/w_150,h_150,c_thumb,g_face,r_20,e_sepia/l_cloudinary_icon,g_south_east,x_5,y_5,w_50,o_60,e_brightness:200/a_10/front_face.png',
#    'width': '174',
#    'height': '174'},
#   'images': {'1': {'item_id': '890289939',
#     'image_id': '1',
#     'src': 'http://res.cloudinary.com/demo/image/upload/w_150,h_150,c_thumb,g_face,r_20,e_sepia/l_cloudinary_icon,g_south_east,x_5,y_5,w_50,o_60,e_brightness:200/a_10/front_face.png',
#     'width': '174',
#     'height': '174',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '890289939',
#     'image_id': '2',
#     'src': 'http://res.cloudinary.com/demo/image/upload/w_250,h_168,c_fit/sample.jpg',
#     'width': '250',
#     'height': '168',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '890289939',
#     'image_id': '3',
#     'src': 'http://res.cloudinary.com/demo/image/upload/w_100,h_150,c_fill/sample.jpg',
#     'width': '100',
#     'height': '150',
#     'credit': '',
#     'caption': ''},
#    '4': {'item_id': '890289939',
#     'image_id': '4',
#     'src': 'http://res.cloudinary.com/demo/image/facebook/w_90,h_98,c_fill,g_face,r_max,e_sepia/billclinton.jpg',
#     'width': '90',
#     'height': '98',
#     'credit': '',
#     'caption': ''}},
#   'listen_duration_estimate': 461},
#  '2839695377': {'item_id': '2839695377',
#   'resolved_id': '144877147',
#   'given_url': 'https://github.com/andrewebdev/django-video/blob/master/setup.py',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898878',
#   'time_updated': '1577898905',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 12,
#   'resolved_title': 'andrewebdev/django-video',
#   'resolved_url': 'https://github.com/andrewebdev/django-video',
#   'excerpt': '© Copyright 2009 Andre Engelbrecht. All Rights Reserved.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '266',
#   'lang': 'en',
#   'top_image_url': 'https://avatars3.githubusercontent.com/u/84479?s=400&v=4',
#   'tags': {'django': {'item_id': '2839695377', 'tag': 'django'},
#    'streaming': {'item_id': '2839695377', 'tag': 'streaming'}},
#   'domain_metadata': {'name': 'GitHub',
#    'logo': 'https://logo.clearbit.com/github.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/github.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 103},
#  '1484325448': {'item_id': '1484325448',
#   'resolved_id': '1484325448',
#   'given_url': 'https://smerity.com/articles/2016/google_nmt_arch.html',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898801',
#   'time_updated': '1577898802',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 13,
#   'resolved_title': "Peeking into the neural network architecture used for Google's Neural Machine Translation",
#   'resolved_url': 'http://smerity.com/articles/2016/google_nmt_arch.html',
#   'excerpt': "The Google Neural Machine Translation paper (GNMT) describes an interesting approach towards deep learning in production. The paper and architecture are non-standard, in many cases deviating far from what you might expect from an architecture you'd find in an academic paper.",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '2843',
#   'lang': 'en',
#   'time_to_read': 13,
#   'top_image_url': 'http://smerity.com/media/images/articles/2016/gnmt_final_architecture.png',
#   'image': {'item_id': '1484325448',
#    'src': 'http://smerity.com/media/images/articles/2016/gnmt_arch_1_enc_dec.svg',
#    'width': '0',
#    'height': '0'},
#   'images': {'1': {'item_id': '1484325448',
#     'image_id': '1',
#     'src': 'http://smerity.com/media/images/articles/2016/gnmt_arch_1_enc_dec.svg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '1484325448',
#     'image_id': '2',
#     'src': 'http://smerity.com/media/images/articles/2016/bahdanau_no_attn.png',
#     'width': '50',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '1484325448',
#     'image_id': '3',
#     'src': 'http://smerity.com/media/images/articles/2016/gnmt_arch_attn.svg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '4': {'item_id': '1484325448',
#     'image_id': '4',
#     'src': 'http://smerity.com/media/images/articles/2016/bahdanau_attn.png',
#     'width': '70',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '5': {'item_id': '1484325448',
#     'image_id': '5',
#     'src': 'http://smerity.com/media/images/articles/2016/gnmt_arch_1_birnn.svg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '6': {'item_id': '1484325448',
#     'image_id': '6',
#     'src': 'http://smerity.com/media/images/articles/2016/gnmt_arch_deep_partial.svg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '7': {'item_id': '1484325448',
#     'image_id': '7',
#     'src': 'http://smerity.com/media/images/articles/2016/gnmt_arch_res.svg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '8': {'item_id': '1484325448',
#     'image_id': '8',
#     'src': 'http://smerity.com/media/images/articles/2016/gnmt_arch_deep_residuals.svg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''}},
#   'listen_duration_estimate': 1101},
#  '2390149666': {'item_id': '2390149666',
#   'resolved_id': '2390149666',
#   'given_url': 'https://towardsdatascience.com/nlp-sequence-to-sequence-networks-part-2-seq2seq-model-encoderdecoder-model-6c22e29fd7e1',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898774',
#   'time_updated': '1577898774',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 14,
#   'resolved_title': 'NLP | Sequence to Sequence Networks| Part 2|Seq2seq Model (EncoderDecoder Model)',
#   'resolved_url': 'https://towardsdatascience.com/nlp-sequence-to-sequence-networks-part-2-seq2seq-model-encoderdecoder-model-6c22e29fd7e1',
#   'excerpt': 'In [NLP | Sequence to Sequence Networks| Part 1| Processing text data] we learnt how to process text data, In this part we will create the model which will take the data we processed and use it to train to translate English sentences to French.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '1',
#   'has_image': '1',
#   'word_count': '831',
#   'lang': 'en',
#   'time_to_read': 4,
#   'top_image_url': 'https://cdn-images-1.medium.com/max/1200/1*_Nb5AADlqVQJDa0YyNFKGA.jpeg',
#   'authors': {'96490310': {'item_id': '2390149666',
#     'author_id': '96490310',
#     'name': "Mohammed Ma'amari",
#     'url': 'https://towardsdatascience.com/@mamarih1'}},
#   'image': {'item_id': '2390149666',
#    'src': 'https://cdn-images-1.medium.com/max/2000/1*_Nb5AADlqVQJDa0YyNFKGA.jpeg',
#    'width': '0',
#    'height': '0'},
#   'images': {'1': {'item_id': '2390149666',
#     'image_id': '1',
#     'src': 'https://cdn-images-1.medium.com/max/2000/1*_Nb5AADlqVQJDa0YyNFKGA.jpeg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '2390149666',
#     'image_id': '2',
#     'src': 'https://cdn-images-1.medium.com/max/1600/0*BpmYIit1tmLKlpDm.png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': 'Encoder Decoder Architecture'},
#    '3': {'item_id': '2390149666',
#     'image_id': '3',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*3lj8AGqfwEE5KCTJ-dXTvg.png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': 'Simple Representation'},
#    '4': {'item_id': '2390149666',
#     'image_id': '4',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*sO-SP58T4brE9EHazHSeGA.png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': 'Generative Model\xa0Chatbots'},
#    '5': {'item_id': '2390149666',
#     'image_id': '5',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*3pH2NH_8i7QMxpV0TFOdxw.jpeg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '6': {'item_id': '2390149666',
#     'image_id': '6',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*sDlV9_-PXBlt8jol-7Xjhg.jpeg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '7': {'item_id': '2390149666',
#     'image_id': '7',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*SMZbHBbXyhhpneqjRqlg6g.png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': 'Model Summary'}},
#   'videos': {'1': {'item_id': '2390149666',
#     'video_id': '1',
#     'src': 'https://towardsdatascience.com/media/85a65caff939525cf0ae85a19bb6caeb?postId=6c22e29fd7e1',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '2': {'item_id': '2390149666',
#     'video_id': '2',
#     'src': 'https://towardsdatascience.com/media/3539fbda2f4e49698e98378ad49ac1d9?postId=6c22e29fd7e1',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '3': {'item_id': '2390149666',
#     'video_id': '3',
#     'src': 'https://towardsdatascience.com/media/eeeb1f24b4fd1cc75752a0422a29c7d1?postId=6c22e29fd7e1',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '4': {'item_id': '2390149666',
#     'video_id': '4',
#     'src': 'https://towardsdatascience.com/media/915b751c02a59a4e5bdd673b22ea07b8?postId=6c22e29fd7e1',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '5': {'item_id': '2390149666',
#     'video_id': '5',
#     'src': 'https://towardsdatascience.com/media/cda3f5fa83e33509a4915993d5d4ef9d?postId=6c22e29fd7e1',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'}},
#   'domain_metadata': {'name': 'Towards Data Science',
#    'logo': 'https://logo.clearbit.com/towardsdatascience.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/towardsdatascience.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 322},
#  '2382199111': {'item_id': '2382199111',
#   'resolved_id': '2382199111',
#   'given_url': 'https://towardsdatascience.com/nlp-sequence-to-sequence-networks-part-1-processing-text-data-d141a5643b72',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898747',
#   'time_updated': '1577898756',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 15,
#   'resolved_title': 'NLP | Sequence to Sequence Networks| Part 1| Processing text\xa0data',
#   'resolved_url': 'https://towardsdatascience.com/nlp-sequence-to-sequence-networks-part-1-processing-text-data-d141a5643b72',
#   'excerpt': 'There are many benefits you can get by understanding NLP, you can make your own model to answer questions and use it in a chat bot, or you can make a translator to translate a text from your language to English language or the opposite, or maybe you make a text summarizer.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '1',
#   'has_image': '1',
#   'word_count': '736',
#   'lang': 'en',
#   'time_to_read': 3,
#   'top_image_url': 'https://cdn-images-1.medium.com/max/1200/1*_Nb5AADlqVQJDa0YyNFKGA.jpeg',
#   'tags': {'nlp': {'item_id': '2382199111', 'tag': 'nlp'}},
#   'authors': {'96490310': {'item_id': '2382199111',
#     'author_id': '96490310',
#     'name': "Mohammed Ma'amari",
#     'url': 'https://towardsdatascience.com/@mamarih1'}},
#   'image': {'item_id': '2382199111',
#    'src': 'https://cdn-images-1.medium.com/max/2600/1*_Nb5AADlqVQJDa0YyNFKGA.jpeg',
#    'width': '0',
#    'height': '0'},
#   'images': {'1': {'item_id': '2382199111',
#     'image_id': '1',
#     'src': 'https://cdn-images-1.medium.com/max/2600/1*_Nb5AADlqVQJDa0YyNFKGA.jpeg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': "Mohammed Ma'amariBlockedUnblockFollowFollowingNov 8, 2018"},
#    '2': {'item_id': '2382199111',
#     'image_id': '2',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*3dJqwlv2TyKvMib0_Lpuww.jpeg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '2382199111',
#     'image_id': '3',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*clOGgaE0nxsJAeJ2kM_hTQ.jpeg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '4': {'item_id': '2382199111',
#     'image_id': '4',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*HRbEaatZ95qs-nlgvr_dXw.jpeg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''}},
#   'videos': {'1': {'item_id': '2382199111',
#     'video_id': '1',
#     'src': 'https://towardsdatascience.com/media/3c64eee18a020e9bc18389d6145cabc0?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '2': {'item_id': '2382199111',
#     'video_id': '2',
#     'src': 'https://towardsdatascience.com/media/1d596b20341f2047cd2499c4d8520bb3?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '3': {'item_id': '2382199111',
#     'video_id': '3',
#     'src': 'https://towardsdatascience.com/media/9d9f8faf466ab1c5fa4c6ff4e3b3a1fc?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '4': {'item_id': '2382199111',
#     'video_id': '4',
#     'src': 'https://towardsdatascience.com/media/63a15cc8eaa216479ec463cc35fc2157?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '5': {'item_id': '2382199111',
#     'video_id': '5',
#     'src': 'https://towardsdatascience.com/media/774b71958e210925c3b98e420989ff7c?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '6': {'item_id': '2382199111',
#     'video_id': '6',
#     'src': 'https://towardsdatascience.com/media/aae4dfbcab38aa7f6a974594e0d47a9a?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '7': {'item_id': '2382199111',
#     'video_id': '7',
#     'src': 'https://towardsdatascience.com/media/b921f083d311ee11bc33a80ef4ef81f6?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '8': {'item_id': '2382199111',
#     'video_id': '8',
#     'src': 'https://towardsdatascience.com/media/2c1b2913045f327c1ba309ec62c68fc1?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '9': {'item_id': '2382199111',
#     'video_id': '9',
#     'src': 'https://towardsdatascience.com/media/6c85b534d3ea9e6934a4b380051e5920?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '10': {'item_id': '2382199111',
#     'video_id': '10',
#     'src': 'https://towardsdatascience.com/media/acc3c090e8e316e07da561e904473504?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'}},
#   'domain_metadata': {'name': 'Towards Data Science',
#    'logo': 'https://logo.clearbit.com/towardsdatascience.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/towardsdatascience.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 285},
#  '174173301': {'item_id': '174173301',
#   'resolved_id': '174173301',
#   'given_url': 'https://fr.wikipedia.org/wiki/Conjonction_(grammaire)',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898727',
#   'time_updated': '1577898728',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 16,
#   'resolved_title': 'Conjonction (grammaire)',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/Conjonction_(grammaire)',
#   'excerpt': 'En grammaire traditionnelle, une conjonction est un mot invariable qui sert à interconnecter deux mots, groupes de mots ou propositions, en exprimant une relation grammaticale, sémantique et logique entre les entités reliées.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '3326',
#   'lang': 'fr',
#   'time_to_read': 17,
#   'authors': {'125921901': {'item_id': '174173301',
#     'author_id': '125921901',
#     'name': 'conjuncționalizare',
#     'url': 'https://dexonline.ro/definitie-dtl/conjunc%C8%9Bionaliz%C3%A1re'}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 1287},
#  '2400166532': {'item_id': '2400166532',
#   'resolved_id': '2400166532',
#   'given_url': 'https://www.ekino.com/articles/handson-de-quelques-taches-courantes-en-nlp',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898526',
#   'time_updated': '1577898538',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 17,
#   'resolved_title': 'Handson de quelques tâches courantes en NLP',
#   'resolved_url': 'https://www.ekino.com/articles/handson-de-quelques-taches-courantes-en-nlp',
#   'excerpt': 'This post is also available in english. Dans ce post, nous allons dérouler quelques exemples de tâches courantes en Natural Language Processing (NLP), en mettant en parallèle deux librairies Python (en) couramment utilisées : NLTK (en) et SpaCy (en).',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '2698',
#   'lang': 'fr',
#   'time_to_read': 13,
#   'top_image_url': 'https://images.ctfassets.net/95wnqgvmhlea/3eM3mJ7BdCSq6OW0y2qiIo/c83970dc36c36bb9e94cee30a0a218aa/15891138064_51f8766cb8_z.jpg?fm=jpg',
#   'tags': {'nlp': {'item_id': '2400166532', 'tag': 'nlp'}},
#   'authors': {'100214772': {'item_id': '2400166532',
#     'author_id': '100214772',
#     'name': 'Pauline Olivier',
#     'url': 'https://www.ekino.com/author/pauline-olivier'}},
#   'image': {'item_id': '2400166532',
#    'src': 'https://images.ctfassets.net/95wnqgvmhlea/3FQn5usy88UciWyAUMSaYm/87f854467cb4898520dcaac3ba754b9d/pytho3.png?fm=png',
#    'width': '0',
#    'height': '0'},
#   'images': {'1': {'item_id': '2400166532',
#     'image_id': '1',
#     'src': 'https://images.ctfassets.net/95wnqgvmhlea/3FQn5usy88UciWyAUMSaYm/87f854467cb4898520dcaac3ba754b9d/pytho3.png?fm=png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '2400166532',
#     'image_id': '2',
#     'src': 'https://images.ctfassets.net/95wnqgvmhlea/6EePj2ewEwQWKI2McqQAAA/e402255fa8702c9eb831c99a6e9548dc/cell.png?fm=png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '2400166532',
#     'image_id': '3',
#     'src': 'https://images.ctfassets.net/95wnqgvmhlea/2lffMyV2ccEuI2cMkqyigs/367f93360c80948ae3e208662724e14a/run.png?fm=png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '4': {'item_id': '2400166532',
#     'image_id': '4',
#     'src': 'https://images.ctfassets.net/95wnqgvmhlea/16Zg0grijueCse6OSKQ0Ok/2d5bdba09b76e9c91d26927a396fb4d5/nltk_tag.png?fm=png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '5': {'item_id': '2400166532',
#     'image_id': '5',
#     'src': 'https://images.ctfassets.net/95wnqgvmhlea/6IiJuGuXugmY6eQyei2e8y/bf2818d4f090fa128893fefef6cf284c/spacy_tag.png?fm=png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''}},
#   'listen_duration_estimate': 1044},
#  '2839690226': {'item_id': '2839690226',
#   'resolved_id': '2839690226',
#   'given_url': 'https://fr.wikipedia.org/wiki/SpaCy',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898456',
#   'time_updated': '1577898466',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 18,
#   'resolved_title': 'SpaCy',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/SpaCy',
#   'excerpt': "En pratique\xa0: Quelles sources sont attendues\xa0? Comment ajouter mes sources\xa0? SpaCy est une bibliothèque logicielle Python de traitement automatique des langues développée par Matt Honnibal de l'entreprise Explosion AI[2].",
#   'is_article': '1',
#   'is_index': '1',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '195',
#   'lang': 'fr',
#   'top_image_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/88/SpaCy_logo.svg/1200px-SpaCy_logo.svg.png',
#   'tags': {'nlp': {'item_id': '2839690226', 'tag': 'nlp'}},
#   'image': {'item_id': '2839690226',
#    'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/88/SpaCy_logo.svg/220px-SpaCy_logo.svg.png',
#    'width': '220',
#    'height': '79'},
#   'images': {'1': {'item_id': '2839690226',
#     'image_id': '1',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/88/SpaCy_logo.svg/220px-SpaCy_logo.svg.png',
#     'width': '220',
#     'height': '79',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '2839690226',
#     'image_id': '2',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a1/2017-fr.wp-orange-source.svg/45px-2017-fr.wp-orange-source.svg.png',
#     'width': '45',
#     'height': '45',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '2839690226',
#     'image_id': '3',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Nuvola_apps_emacs.png/24px-Nuvola_apps_emacs.png',
#     'width': '24',
#     'height': '24',
#     'credit': '',
#     'caption': ''},
#    '4': {'item_id': '2839690226',
#     'image_id': '4',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Logo_proba_4.svg/31px-Logo_proba_4.svg.png',
#     'width': '31',
#     'height': '24',
#     'credit': '',
#     'caption': ''}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 75},
#  '60275390': {'item_id': '60275390',
#   'resolved_id': '60275390',
#   'given_url': 'https://fr.wikipedia.org/wiki/Scala_(langage)',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898320',
#   'time_updated': '1577898320',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 19,
#   'resolved_title': 'Scala (langage)',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/Scala_(langage)',
#   'excerpt': "Scala est un langage de programmation multi-paradigme conçu à l'École polytechnique fédérale de Lausanne (EPFL) pour exprimer les modèles de programmation courants dans une forme concise et élégante.",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '686',
#   'lang': 'fr',
#   'time_to_read': 3,
#   'image': {'item_id': '60275390',
#    'src': 'https://fr.wikipedia.org/wiki/Fichier:Scala.png',
#    'width': '131',
#    'height': '37'},
#   'images': {'1': {'item_id': '60275390',
#     'image_id': '1',
#     'src': 'https://fr.wikipedia.org/wiki/Fichier:Scala.png',
#     'width': '131',
#     'height': '37',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '60275390',
#     'image_id': '2',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/cc/Circle-icons-dev.svg/24px-Circle-icons-dev.svg.png',
#     'width': '24',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail de la programmation informatique'}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 266},
#  '2690910611': {'item_id': '2690910611',
#   'resolved_id': '2690910611',
#   'given_url': 'http://mobile.interieur.gouv.fr/Actualites/L-actu-du-Ministere/Alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577897973',
#   'time_updated': '1577897974',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 20,
#   'resolved_title': 'Alicem, la première solution d’identité numérique régalienne sécurisée',
#   'resolved_url': 'https://mobile.interieur.gouv.fr/Actualites/L-actu-du-Ministere/Alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee',
#   'excerpt': "Alicem est une application pour smartphone développée par le ministère de l’Intérieur et l’Agence nationale des titres sécurisés (ANTS) qui permet à tout particulier, qui décide de l'utiliser, de prouver son identité sur Internet de manière sécurisée.",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '638',
#   'lang': 'fr',
#   'time_to_read': 3,
#   'top_image_url': 'http://mobile.interieur.gouv.fr/var/miomcti/storage/images/www.interieur.gouv.fr/version-fre/actualites/l-actu-du-ministere/alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee/936936-1-fre-FR/Alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee.jpg',
#   'authors': {'1214917': {'item_id': '2690910611',
#     'author_id': '1214917',
#     'name': "Ministère de l'Intérieur",
#     'url': ''}},
#   'image': {'item_id': '2690910611',
#    'src': 'https://mobile.interieur.gouv.fr/var/miomcti/storage/images/www.interieur.gouv.fr/version-fre/actualites/l-actu-du-ministere/alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee/936936-1-fre-FR/Alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee_catcher.jpg',
#    'width': '452',
#    'height': '212'},
#   'images': {'1': {'item_id': '2690910611',
#     'image_id': '1',
#     'src': 'https://mobile.interieur.gouv.fr/var/miomcti/storage/images/www.interieur.gouv.fr/version-fre/actualites/l-actu-du-ministere/alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee/936936-1-fre-FR/Alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee_catcher.jpg',
#     'width': '452',
#     'height': '212',
#     'credit': '',
#     'caption': ''}},
#   'listen_duration_estimate': 247},
#  '1384026401': {'item_id': '1384026401',
#   'resolved_id': '1384026401',
#   'given_url': 'https://stackabuse.com/reading-and-writing-json-to-a-file-in-python/',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577897919',
#   'time_updated': '1577897919',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 21,
#   'resolved_title': 'Reading and Writing JSON to a File in Python',
#   'resolved_url': 'https://stackabuse.com/reading-and-writing-json-to-a-file-in-python/',
#   'excerpt': "Over the last 5-10 years, the JSON format has been one of, if not the most, popular ways to serialize data. Especially in the web development world, you'll likely encounter JSON through one of the many REST APIs, application configuration, or even simple data storage.",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '1037',
#   'lang': 'en',
#   'time_to_read': 5,
#   'authors': {'2526517': {'item_id': '1384026401',
#     'author_id': '2526517',
#     'name': 'Scott Robinson',
#     'url': ''}},
#   'listen_duration_estimate': 401},
#  '91274609': {'item_id': '91274609',
#   'resolved_id': '91274609',
#   'given_url': 'https://fr.wikipedia.org/wiki/Comet_(informatique)',
#   'given_title': 'Comet (informatique) — Wikipédia',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1576930551',
#   'time_updated': '1576930564',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 22,
#   'resolved_title': 'Comet (informatique)',
# ...
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '2',
#   'has_image': '1',
#   'word_count': '0',
#   'lang': 'es',
#   'tags': {'before the flood': {'item_id': '2075605116',
#     'tag': 'before the flood'},
#    'documentary': {'item_id': '2075605116', 'tag': 'documentary'}},
#   'image': {'item_id': '2075605116',
#    'src': 'http://img.youtube.com/vi/NCqjCQdYgRk/maxresdefault.jpg',
#    'width': '480',
#    'height': '360'},
#   'images': {'1': {'item_id': '2075605116',
#     'image_id': '1',
#     'src': 'http://img.youtube.com/vi/NCqjCQdYgRk/maxresdefault.jpg',
#     'width': '480',
#     'height': '360',
#     'credit': '',
#     'caption': ''}},
#   'videos': {'1': {'item_id': '2075605116',
#     'video_id': '1',
#     'src': 'http://www.youtube.com/watch?v=NCqjCQdYgRk',
#     'width': '0',
#     'height': '0',
#     'type': '1',
#     'vid': 'NCqjCQdYgRk',
#     'length': '343'}},
#   'domain_metadata': {'name': 'YouTube',
#    'logo': 'https://logo.clearbit.com/youtube.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/youtube.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 0},
#  '335239985': {'item_id': '335239985',
#   'resolved_id': '335239985',
#   'given_url': 'https://fr.wikipedia.org/wiki/Robert_Crumb',
#   'given_title': 'Robert Crumb — Wikipédia',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1518781561',
#   'time_updated': '1554628225',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 117,
#   'resolved_title': 'Robert Crumb',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/Robert_Crumb',
#   'excerpt': 'Robert Crumb est un auteur de bande dessinée américain, et un musicien compositeur, né à Philadelphie le 30 août 1943.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '3264',
#   'lang': 'fr',
#   'time_to_read': 16,
#   'top_image_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/55/Robert_Crumb%2C_2014_%28cropped%29.JPG/1200px-Robert_Crumb%2C_2014_%28cropped%29.JPG',
#   'tags': {'before the flood': {'item_id': '335239985',
#     'tag': 'before the flood'},
#    'documentary': {'item_id': '335239985', 'tag': 'documentary'}},
#   'authors': {'5937251': {'item_id': '335239985',
#     'author_id': '5937251',
#     'name': 'Comics Code Authority',
#     'url': 'https://fr.wikipedia.org/wiki/Comics_Code_Authority'}},
#   'image': {'item_id': '335239985',
#    'src': 'https://fr.wikipedia.org/wiki/Fichier:Robert_Crumb,_2014_(cropped).JPG',
#    'width': '220',
#    'height': '311'},
#   'images': {'1': {'item_id': '335239985',
#     'image_id': '1',
#     'src': 'https://fr.wikipedia.org/wiki/Fichier:Robert_Crumb,_2014_(cropped).JPG',
#     'width': '220',
#     'height': '311',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '335239985',
#     'image_id': '2',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/03/Flag_of_Italy.svg/20px-Flag_of_Italy.svg.png',
#     'width': '20',
#     'height': '13',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '335239985',
#     'image_id': '3',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Flag_of_Sweden.svg/20px-Flag_of_Sweden.svg.png',
#     'width': '20',
#     'height': '13',
#     'credit': '',
#     'caption': ''},
#    '4': {'item_id': '335239985',
#     'image_id': '4',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/20px-Flag_of_France.svg.png',
#     'width': '20',
#     'height': '13',
#     'credit': '',
#     'caption': ''},
#    '5': {'item_id': '335239985',
#     'image_id': '5',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Flag_of_Spain.svg/20px-Flag_of_Spain.svg.png',
#     'width': '20',
#     'height': '13',
#     'credit': '',
#     'caption': ''},
#    '6': {'item_id': '335239985',
#     'image_id': '6',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/5f/WBDbulle2.svg/25px-WBDbulle2.svg.png',
#     'width': '25',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail de la bande dessinée'},
#    '7': {'item_id': '335239985',
#     'image_id': '7',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/1f/AnarchySymbolInk.svg/23px-AnarchySymbolInk.svg.png',
#     'width': '23',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail de l’anarchisme'},
#    '8': {'item_id': '335239985',
#     'image_id': '8',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png',
#     'width': '46',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail des États-Unis'}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 1263},
#  '323301344': {'item_id': '323301344',
#   'resolved_id': '323301344',
#   'given_url': 'https://fr.wikipedia.org/wiki/Lou_Reed',
#   'given_title': 'Lou Reed — Wikipédia',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1518781545',
#   'time_updated': '1554628194',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 118,
#   'resolved_title': 'Lou Reed',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/Lou_Reed',
#   'excerpt': 'Lou Reed (2 mars 1942 à Brooklyn, New York - 27 octobre 2013 à Southampton, Long Island, New York) est un auteur-compositeur-interprète américain qui a commencé sa carrière avec le groupe The Velvet Underground.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '3354',
#   'lang': 'fr',
#   'time_to_read': 17,
#   'top_image_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Lou_Reed_%285900962918%29.jpg/1200px-Lou_Reed_%285900962918%29.jpg',
#   'tags': {'before the flood': {'item_id': '323301344',
#     'tag': 'before the flood'},
#    'documentary': {'item_id': '323301344', 'tag': 'documentary'}},
#   'authors': {'218929': {'item_id': '323301344',
#     'author_id': '218929',
#     'name': 'Andy Warhol',
#     'url': ''}},
#   'image': {'item_id': '323301344',
#    'src': 'https://fr.wikipedia.org/wiki/Fichier:Lou_Reed_(5900962918).jpg',
#    'width': '220',
#    'height': '173'},
#   'images': {'1': {'item_id': '323301344',
#     'image_id': '1',
#     'src': 'https://fr.wikipedia.org/wiki/Fichier:Lou_Reed_(5900962918).jpg',
#     'width': '220',
#     'height': '173',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '323301344',
#     'image_id': '2',
#     'src': 'https://fr.wikipedia.org/wiki/Fichier:Lou_Reed_HS_Yearbook_(cropped).jpg',
#     'width': '170',
#     'height': '195',
#     'credit': '',
#     'caption': 'Lou Reed en 1959'},
#    '3': {'item_id': '323301344',
#     'image_id': '3',
#     'src': 'https://fr.wikipedia.org/wiki/Fichier:Lou_Reed_1977.JPG',
#     'width': '170',
#     'height': '239',
#     'credit': '',
#     'caption': 'Lou Reed en 1977'},
#    '5': {'item_id': '323301344',
#     'image_id': '5',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/57/E-Guitare-horiz.png/48px-E-Guitare-horiz.png',
#     'width': '48',
#     'height': '19',
#     'credit': '',
#     'caption': 'Portail de la guitare'},
#    '6': {'item_id': '323301344',
#     'image_id': '6',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/ac/Musical_notes.svg/32px-Musical_notes.svg.png',
#     'width': '32',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail de la musique'},
#    '7': {'item_id': '323301344',
#     'image_id': '7',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Flag_of_New_York_City.svg/37px-Flag_of_New_York_City.svg.png',
#     'width': '37',
#     'height': '22',
#     'credit': '',
#     'caption': 'Portail de New York'}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 1298},
#  '9142472': {'item_id': '9142472',
#   'resolved_id': '9142472',
#   'given_url': 'https://www.urbandictionary.com/define.php?term=fo%27%20shizzle%20my%20nizzle',
#   'given_title': "Urban Dictionary: fo' shizzle my nizzle",
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1518086610',
#   'time_updated': '1522744494',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 119,
#   'resolved_title': "fo' shizzle my nizzle",
#   'resolved_url': 'http://www.urbandictionary.com/define.php?term=fo%27%20shizzle%20my%20nizzle',
#   'excerpt': '',
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '1',
#   'has_image': '1',
#   'word_count': '0',
#   'lang': 'en',
#   'tags': {'darijadmerikan': {'item_id': '9142472', 'tag': 'darijadmerikan'},
#    'vocab': {'item_id': '9142472', 'tag': 'vocab'}},
#   'authors': {'6488759': {'item_id': '9142472',
#     'author_id': '6488759',
#     'name': 'anonymous',
#     'url': 'http://www.urbandictionary.com/author.php?author=anonymous'}},
#   'image': {'item_id': '9142472',
#    'src': 'http://img.youtube.com/vi/JPOZd-XMZeo/0.jpg',
#    'width': '480',
#    'height': '360'},
#   'images': {'1': {'item_id': '9142472',
#     'image_id': '1',
#     'src': 'http://img.youtube.com/vi/JPOZd-XMZeo/0.jpg',
#     'width': '480',
#     'height': '360',
#     'credit': '',
#     'caption': ''}},
#   'videos': {'1': {'item_id': '9142472',
#     'video_id': '1',
#     'src': 'http://www.youtube.com/embed/JPOZd-XMZeo?playlist=&showinfo=1&rel=0&wmode=transparent',
#     'width': '425',
#     'height': '349',
#     'type': '1',
#     'vid': 'JPOZd-XMZeo',
#     'length': '0'}},
#   'listen_duration_estimate': 0},
#  '2064210780': {'item_id': '2064210780',
#   'resolved_id': '2064210780',
#   'given_url': 'http://www.wordreference.com/enfr/go%20through',
#   'given_title': 'go through - English-French Dictionary WordReference.com',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1518086393',
#   'time_updated': '1518086423',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 120,
#   'resolved_title': '',
#   'resolved_url': 'http://www.wordreference.com/enfr/go%20through',
#   'excerpt': '',
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '0',
#   'lang': '',
#   'tags': {'english': {'item_id': '2064210780', 'tag': 'english'},
#    'vocab': {'item_id': '2064210780', 'tag': 'vocab'}},
#   'listen_duration_estimate': 0},
#  '2064210468': {'item_id': '2064210468',
#   'resolved_id': '2064210468',
#   'given_url': 'https://dictionary.cambridge.org/fr/dictionnaire/anglais/work-through-something',
#   'given_title': 'work through something définition dans le dictionnaire Anglais de Cambridge',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1518086368',
#   'time_updated': '1518086377',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 121,
#   'resolved_title': 'work through something définition dans le dictionnaire Anglais de Cambridge',
#   'resolved_url': 'https://dictionary.cambridge.org/fr/dictionnaire/anglais/work-through-something',
#   'excerpt': 'Définition anglaise de “work through something”                        (Definition of “work through something” from the Cambridge Academic Content Dictionary © Cambridge University Press)',
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '20',
#   'lang': 'en',
#   'amp_url': 'https://dictionary.cambridge.org/fr/amp/anglais/work-through-something',
#   'top_image_url': 'https://dictionary.cambridge.org/fr/external/images/CDO_logo_120x120.jpg?version=3.1.89',
#   'tags': {'english': {'item_id': '2064210468', 'tag': 'english'},
#    'vocab': {'item_id': '2064210468', 'tag': 'vocab'}},
#   'listen_duration_estimate': 8},
#  '2064207864': {'item_id': '2064207864',
#   'resolved_id': '2064207864',
#   'given_url': 'https://www.urbandictionary.com/define.php?term=sb.%20ain%27t%20got%20shit%20on%20me',
#   'given_title': "Urban Dictionary: sb. ain't got shit on me",
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1518086173',
#   'time_updated': '1518783749',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 122,
#   'resolved_title': "sb. ain't got shit on me",
#   'resolved_url': 'https://www.urbandictionary.com/define.php?term=sb.%20ain%27t%20got%20shit%20on%20me',
#   'excerpt': '',
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '0',
#   'lang': 'en',
#   'amp_url': 'https://www.urbandictionary.com/define.php?term=sb.%20ain%27t%20got%20shit%20on%20me&amp=true',
#   'tags': {'expression': {'item_id': '2064207864', 'tag': 'expression'},
#    'urban': {'item_id': '2064207864', 'tag': 'urban'},
#    'vocab': {'item_id': '2064207864', 'tag': 'vocab'}},
#   'authors': {'83719120': {'item_id': '2064207864',
#     'author_id': '83719120',
#     'name': 'C-Webb',
#     'url': 'https://www.urbandictionary.com/author.php?author=C-Webb'}},
#   'listen_duration_estimate': 0},
#  '2011690338': {'item_id': '2011690338',
#   'resolved_id': '2011690338',
#   'given_url': 'http://www.marrakech-cityguide.com/site-archeologique-de-aghmat-3187',
#   'given_title': 'Site archéologique de AGHMAT à 32 km de Marrakech',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1514897227',
#   'time_updated': '1514903673',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 123,
#   'resolved_title': 'Site archéologique de AGHMAT',
#   'resolved_url': 'http://www.marrakech-cityguide.com/site-archeologique-de-aghmat-3187',
#   'excerpt': 'Aghmat, est située à 32 km de Marrakech sur la route de l’Ourika, province de Al Haouz, c’est aussi une commune rurale locale créé en 1959.   La ville de Aghmat est considérée comme étant la plus ancienne ville marocaine, érigée même avant l’entrée de l’Islam au Maroc.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '225',
#   'lang': 'fr',
#   'amp_url': 'http://www.marrakech-cityguide.com/site-archeologique-de-aghmat-3187/amp/',
#   'top_image_url': 'http://www.marrakech-cityguide.com/wp-content/uploads/IMG_1311.jpg',
#   'tags': {'archéologie': {'item_id': '2011690338', 'tag': 'archéologie'},
#    'marrakech': {'item_id': '2011690338', 'tag': 'marrakech'},
#    'voyage': {'item_id': '2011690338', 'tag': 'voyage'}},
#   'authors': {'49416574': {'item_id': '2011690338',
#     'author_id': '49416574',
#     'name': 'Pierre-Marie Coupry',
#     'url': 'http://www.marrakech-cityguide.com/author/pm-seo/'}},
#   'image': {'item_id': '2011690338',
#    'src': 'http://www.marrakech-cityguide.com/wp-content/uploads/IMG_1311-620x420.jpg',
#    'width': '620',
#    'height': '420'},
#   'images': {'1': {'item_id': '2011690338',
#     'image_id': '1',
#     'src': 'http://www.marrakech-cityguide.com/wp-content/uploads/IMG_1311-620x420.jpg',
#     'width': '620',
#     'height': '420',
#     'credit': '',
#     'caption': ''}},
#   'listen_duration_estimate': 87},
#  '2005265162': {'item_id': '2005265162',
#   'resolved_id': '2005265162',
#   'given_url': 'https://www.bizjournals.com/sanjose/news/2017/12/26/artificial-intelligence-talent-shortage-salaries.html',
#   'given_title': 'Artificial intelligence hindered by talent shortage, according to Ernst & Y',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1514851243',
#   'time_updated': '1514903757',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 124,
#   'resolved_title': '',
#   'resolved_url': 'https://www.bizjournals.com/sanjose/news/2017/12/26/artificial-intelligence-talent-shortage-salaries.html',
#   'excerpt': '',
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '0',
#   'lang': 'en',
#   'tags': {'artificial intelligence': {'item_id': '2005265162',
#     'tag': 'artificial intelligence'}},
#   'domain_metadata': {'name': 'The Business Journals',
#    'logo': 'https://logo.clearbit.com/bizjournals.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/bizjournals.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 0}}

# %%
tags_list = []
for k,v in tags_dict.items():
    tags_list.append(v)
tags_list
# Out:
# [{'item_id': '698231177',
#   'resolved_id': '698231177',
#   'given_url': 'https://fr.wikipedia.org/wiki/SHRDLU',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585673652',
#   'time_updated': '1585673660',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 0,
#   'resolved_title': 'SHRDLU',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/SHRDLU',
#   'excerpt': 'SHRDLU a été l’un des premiers programmes informatiques de compréhension du langage naturel, développé par Terry Winograd au MIT à partir de 1968-1970. Il était écrit en Micro Planner et en Lisp et implémenté sur un ordinateur PDP-6 de DEC équipé d’un terminal graphique DEC.',
#   'is_article': '1',
#   'is_index': '1',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '814',
#   'lang': 'fr',
#   'time_to_read': 4,
#   'top_image_url': 'https://upload.wikimedia.org/wikipedia/commons/b/bc/Shrdlu-original.jpg',
#   'tags': {'nlp': {'item_id': '698231177', 'tag': 'nlp'}},
#   'image': {'item_id': '698231177',
#    'src': 'https://fr.wikipedia.org/wiki/Fichier:Shrdlu-original.jpg',
#    'width': '220',
#    'height': '177'},
#   'images': {'1': {'item_id': '698231177',
#     'image_id': '1',
#     'src': 'https://fr.wikipedia.org/wiki/Fichier:Shrdlu-original.jpg',
#     'width': '220',
#     'height': '177',
#     'credit': '',
#     'caption': "Le logiciel présente un monde avec des blocs de différentes formes. L'utilisateur peut modifier le monde en donnant des instructions en langue naturelle."},
#    '2': {'item_id': '698231177',
#     'image_id': '2',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/02/Circle-icons-computer.svg/24px-Circle-icons-computer.svg.png',
#     'width': '24',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail de l’informatique'}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 315},
#  {'item_id': '12558068',
#   'resolved_id': '12558068',
#   'given_url': 'https://fr.wikipedia.org/wiki/Th%C3%A9orie_algorithmique_de_l%27information',
#   'given_title': "Théorie algorithmique de l'information — Wikipédia",
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585670987',
#   'time_updated': '1585670997',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 1,
#   'resolved_title': "Théorie algorithmique de l'information",
#   'resolved_url': 'https://fr.wikipedia.org/wiki/Th%C3%A9orie_algorithmique_de_l%27information',
#   'excerpt': "La théorie algorithmique de l'information, initiée par Kolmogorov, Solomonov et Chaitin dans les années 1960, vise à quantifier et qualifier le contenu en information d'un ensemble de données, en utilisant la théorie de la calculabilité et la notion de machine universelle de Turing.",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '579',
#   'lang': 'fr',
#   'time_to_read': 3,
#   'tags': {'théories': {'item_id': '12558068', 'tag': 'théories'}},
#   'authors': {'3359036': {'item_id': '12558068',
#     'author_id': '3359036',
#     'name': 'biologie',
#     'url': 'https://fr.wikipedia.org/wiki/Biologie'}},
#   'image': {'item_id': '12558068',
#    'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Max-cut.svg/30px-Max-cut.svg.png',
#    'width': '30',
#    'height': '24'},
#   'images': {'1': {'item_id': '12558068',
#     'image_id': '1',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Max-cut.svg/30px-Max-cut.svg.png',
#     'width': '30',
#     'height': '24',
#     'credit': '',
#     'caption': "Portail de l'informatique théorique"}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 224},
#  {'item_id': '2448904635',
#   'resolved_id': '2448904635',
#   'given_url': 'https://stackoverflow.com/questions/50236117/scraping-ssl-certificate-verify-failed-error-for-http-en-wikipedia-org',
#   'given_title': 'python - Scraping: SSL: CERTIFICATE_VERIFY_FAILED error for http://en.wikip',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585646877',
#   'time_updated': '1585646885',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 2,
#   'resolved_title': 'Scraping: SSL: CERTIFICATE_VERIFY_FAILED error for http://en.wikipedia.org',
#   'resolved_url': 'https://stackoverflow.com/questions/50236117/scraping-ssl-certificate-verify-failed-error-for-http-en-wikipedia-org',
#   'excerpt': "Btw,I was also practicing scrapy, but kept getting the problem: command not found: scrapy (I tried all sorts of solutions online but none works... really frustrating) Once upon a time I stumbled with this issue. If you're using macOS go to Macintosh HD > Applications > Python3.",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '634',
#   'lang': 'en',
#   'time_to_read': 3,
#   'top_image_url': 'https://cdn.sstatic.net/Sites/stackoverflow/img/apple-touch-icon@2.png?v=73d79a89bded',
#   'tags': {'ssl: certificate_verify_f': {'item_id': '2448904635',
#     'tag': 'ssl: certificate_verify_f'},
#    'urlib': {'item_id': '2448904635', 'tag': 'urlib'}},
#   'authors': {'37243038': {'item_id': '2448904635',
#     'author_id': '37243038',
#     'name': 'smci',
#     'url': 'https://stackoverflow.com/users/202229/smci'},
#    '103000012': {'item_id': '2448904635',
#     'author_id': '103000012',
#     'name': 'Catherine4j',
#     'url': 'https://stackoverflow.com/users/9759042/catherine4j'}},
#   'image': {'item_id': '2448904635',
#    'src': 'https://graph.facebook.com/615748615301068/picture?type=large',
#    'width': '32',
#    'height': '32'},
#   'images': {'1': {'item_id': '2448904635',
#     'image_id': '1',
#     'src': 'https://graph.facebook.com/615748615301068/picture?type=large',
#     'width': '32',
#     'height': '32',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '2448904635',
#     'image_id': '2',
#     'src': 'https://i.stack.imgur.com/uUU4m.jpg?s=32&g=1',
#     'width': '32',
#     'height': '32',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '2448904635',
#     'image_id': '3',
#     'src': 'https://graph.facebook.com/1437199476299721/picture?type=large',
#     'width': '32',
#     'height': '32',
#     'credit': '',
#     'caption': ''}},
#   'domain_metadata': {'name': 'Stack Overflow',
#    'logo': 'https://logo.clearbit.com/stackoverflow.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/stackoverflow.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 245},
#  {'item_id': '2931905469',
#   'resolved_id': '2931905469',
#   'given_url': 'https://towardsdatascience.com/15-python-libraries-that-a-data-scientist-need-to-know-df0b3029ecd9',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585570363',
#   'time_updated': '1585672491',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 3,
#   'resolved_title': '15 Python Libraries That A Data Scientist Need To Know',
#   'resolved_url': 'https://towardsdatascience.com/15-python-libraries-that-a-data-scientist-need-to-know-df0b3029ecd9',
#   'excerpt': 'If you are a Data Scientist, Data Analyst or just an enthusiast, you should not miss some extremely popular and useful libraries for Python. In this article, totally 15 Python libraries will be listed and briefly introduced.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '2053',
#   'lang': 'en',
#   'time_to_read': 9,
#   'top_image_url': 'https://miro.medium.com/max/1200/1*A4sZ2qS0jxVmeA3qGba0ag.jpeg',
#   'tags': {'data science': {'item_id': '2931905469', 'tag': 'data science'}},
#   'authors': {'128552945': {'item_id': '2931905469',
#     'author_id': '128552945',
#     'name': 'Christopher Tao',
#     'url': 'https://towardsdatascience.com/@qiuyujx'}},
#   'image': {'item_id': '2931905469',
#    'src': 'https://miro.medium.com/max/3840/1*H4zCeuFMabhJfegvAw6UGg.jpeg',
#    'width': '1920',
#    'height': '728'},
#   'images': {'1': {'item_id': '2931905469',
#     'image_id': '1',
#     'src': 'https://miro.medium.com/max/3840/1*H4zCeuFMabhJfegvAw6UGg.jpeg',
#     'width': '1920',
#     'height': '728',
#     'credit': 'Pexels on Pixabay',
#     'caption': ''},
#    '2': {'item_id': '2931905469',
#     'image_id': '2',
#     'src': 'https://miro.medium.com/fit/c/96/96/1*aL2isee1E3zr8mzSXRiASA.png',
#     'width': '48',
#     'height': '48',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '2931905469',
#     'image_id': '3',
#     'src': 'https://miro.medium.com/max/3840/1*Lf64_S5ZAHrr9EvKJNcN7Q.jpeg',
#     'width': '1920',
#     'height': '1080',
#     'credit': 'geralt on Pixabay',
#     'caption': ''},
#    '4': {'item_id': '2931905469',
#     'image_id': '4',
#     'src': 'https://miro.medium.com/max/3840/1*RsLC2ruXUKt-rSF_BtCsog.jpeg',
#     'width': '1920',
#     'height': '1271',
#     'credit': 'Sztrapacska74 on Pixabay',
#     'caption': ''},
#    '5': {'item_id': '2931905469',
#     'image_id': '5',
#     'src': 'https://miro.medium.com/max/3840/1*A4sZ2qS0jxVmeA3qGba0ag.jpeg',
#     'width': '1920',
#     'height': '1271',
#     'credit': '6689062 on Pixabay',
#     'caption': ''},
#    '6': {'item_id': '2931905469',
#     'image_id': '6',
#     'src': 'https://miro.medium.com/max/3840/1*BL2DLU5dRn8OpLnXN7iU3A.jpeg',
#     'width': '1920',
#     'height': '1280',
#     'credit': 'FeeLoona on Pixabay',
#     'caption': ''},
#    '7': {'item_id': '2931905469',
#     'image_id': '7',
#     'src': 'https://miro.medium.com/max/3840/1*u6mk-djp_nE722Ap7zi1vg.jpeg',
#     'width': '1920',
#     'height': '1080',
#     'credit': 'Pexels on Pixabay',
#     'caption': ''},
#    '8': {'item_id': '2931905469',
#     'image_id': '8',
#     'src': 'https://miro.medium.com/max/2560/1*s_f1PwQw0pE3u0olLE-sWw.png',
#     'width': '1280',
#     'height': '1012',
#     'credit': '200degrees on Pixabay',
#     'caption': ''},
#    '9': {'item_id': '2931905469',
#     'image_id': '9',
#     'src': 'https://miro.medium.com/max/6000/0*w1iPf1hmDWwRnNuz',
#     'width': '3000',
#     'height': '2000',
#     'credit': 'Kelly Sikkema on Unsplash',
#     'caption': ''}},
#   'domain_metadata': {'name': 'Towards Data Science',
#    'logo': 'https://logo.clearbit.com/towardsdatascience.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/towardsdatascience.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 795},
#  {'item_id': '443041106',
#   'resolved_id': '443041106',
#   'given_url': 'https://fr.wikipedia.org/wiki/Dalvik_(machine_virtuelle)',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585152989',
#   'time_updated': '1585152990',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 4,
#   'resolved_title': 'Dalvik (machine virtuelle)',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/Dalvik_(machine_virtuelle)',
#   'excerpt': "Dalvik est une machine virtuelle destinée aux téléphones mobiles et tablettes tactiles, qui est incorporée dans le système d'exploitation Android[1],[2].",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '692',
#   'lang': 'fr',
#   'time_to_read': 3,
#   'image': {'item_id': '443041106',
#    'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/02/Circle-icons-computer.svg/24px-Circle-icons-computer.svg.png',
#    'width': '24',
#    'height': '24'},
#   'images': {'1': {'item_id': '443041106',
#     'image_id': '1',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/02/Circle-icons-computer.svg/24px-Circle-icons-computer.svg.png',
#     'width': '24',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail de l’informatique'},
#    '2': {'item_id': '443041106',
#     'image_id': '2',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/03/Crystal_Clear_app_kpackage.png/24px-Crystal_Clear_app_kpackage.png',
#     'width': '24',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail du logiciel'}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 268},
#  {'item_id': '2927649046',
#   'resolved_id': '2927649046',
#   'given_url': 'https://www.google.com/search?q=nombre+mixte&rlz=1C9BKJA_enFR840FR840&oq=nombre+mixte&aqs=chrome..69i57.4206j0j4&hl=fr&sourceid=chrome-mobile&ie=UTF-8',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585151923',
#   'time_updated': '1585151980',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 5,
#   'resolved_title': 'nombre mixte',
#   'resolved_url': 'https://www.google.com/search?q=nombre+mixte&rlz=1C9BKJA_enFR840FR840&oq=nombre+mixte&aqs=chrome..69i57.4206j0j4&hl=fr&sourceid=chrome-mobile&ie=UTF-8',
#   'excerpt': "5 mai 2017 · Dans cette série de vidéos, les enfants découvriront les nombres mixtes. IL s'agit d'une manière ...",
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '19',
#   'lang': 'fr',
#   'tags': {'quizup': {'item_id': '2927649046', 'tag': 'quizup'}},
#   'domain_metadata': {'name': 'Google',
#    'logo': 'https://logo.clearbit.com/google.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/google.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 7},
#  {'item_id': '2927648143',
#   'resolved_id': '2927648143',
#   'given_url': 'https://fr.wikipedia.org/wiki/GX-4000',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585151867',
#   'time_updated': '1585151900',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 6,
#   'resolved_title': 'GX-4000',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/GX-4000',
#   'excerpt': "La GX-4000 est une console de jeux vidéo 8 bits d'Amstrad mise en vente en 1990. Elle est construite sur une base d'Amstrad CPC Plus et partage donc les mêmes caractéristiques que celui-ci. En 1989, les CPC se retrouvent complètement dépassés par les nouvelles machines 16 bits.",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '667',
#   'lang': 'fr',
#   'time_to_read': 3,
#   'top_image_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Amstrad-GX4000-Console-Set.png/1200px-Amstrad-GX4000-Console-Set.png',
#   'tags': {'quizup': {'item_id': '2927648143', 'tag': 'quizup'}},
#   'image': {'item_id': '2927648143',
#    'src': 'https://fr.wikipedia.org/wiki/Fichier:Amstrad-GX4000-Console-Set.png',
#    'width': '280',
#    'height': '116'},
#   'images': {'1': {'item_id': '2927648143',
#     'image_id': '1',
#     'src': 'https://fr.wikipedia.org/wiki/Fichier:Amstrad-GX4000-Console-Set.png',
#     'width': '280',
#     'height': '116',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '2927648143',
#     'image_id': '2',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/05/Crystal_Clear_app_package_games.png/24px-Crystal_Clear_app_package_games.png',
#     'width': '24',
#     'height': '24',
#     'credit': '',
#     'caption': ''}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 258},
#  {'item_id': '2927298340',
#   'resolved_id': '2927298340',
#   'given_url': 'https://blog.transloc.com/blog/what-is-gtfs-why-does-it-matter-public-transit',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585127858',
#   'time_updated': '1585127887',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 7,
#   'resolved_title': 'GTFS – What is it and why does it matter to public transit?',
#   'resolved_url': 'https://blog.transloc.com/blog/what-is-gtfs-why-does-it-matter-public-transit',
#   'excerpt': 'In my first few weeks of working at TransLoc, I frequently heard the term “GTFS feeds” passed around. Even after I was given a run-down of what it meant, I didn’t have a firm grasp of what GTFS feeds were and why they were actually important to transit agencies.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '1',
#   'has_image': '1',
#   'word_count': '764',
#   'lang': 'en',
#   'time_to_read': 3,
#   'amp_url': 'https://blog.transloc.com/blog/what-is-gtfs-why-does-it-matter-public-transit?hs_amp=true',
#   'top_image_url': 'https://blog.transloc.com/hubfs/GTFS%20post%20title_600x200@2x.png#keepProtocol',
#   'tags': {'google': {'item_id': '2927298340', 'tag': 'google'},
#    'tech': {'item_id': '2927298340', 'tag': 'tech'}},
#   'authors': {'81717026': {'item_id': '2927298340',
#     'author_id': '81717026',
#     'name': 'TransLoc Marketing',
#     'url': ''}},
#   'image': {'item_id': '2927298340',
#    'src': 'http://img.youtube.com/vi/NYkuBJTlOls/0.jpg',
#    'width': '480',
#    'height': '360'},
#   'images': {'1': {'item_id': '2927298340',
#     'image_id': '1',
#     'src': 'http://img.youtube.com/vi/NYkuBJTlOls/0.jpg',
#     'width': '480',
#     'height': '360',
#     'credit': '',
#     'caption': ''}},
#   'videos': {'1': {'item_id': '2927298340',
#     'video_id': '1',
#     'src': 'https://www.youtube.com/embed/NYkuBJTlOls?wmode=transparent',
#     'width': '560',
#     'height': '315',
#     'type': '1',
#     'vid': 'NYkuBJTlOls',
#     'length': '0'}},
#   'listen_duration_estimate': 296},
#  {'item_id': '2926302281',
#   'resolved_id': '2926302281',
#   'given_url': 'https://fr.appewa.com/reader/bb12496e-ebdf-4045-8fad-a3959d0353c7/article',
#   'given_title': "Apprendre l'Anglais en ligne - Écouter et parler avec EWA",
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1585051993',
#   'time_updated': '1585067824',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 8,
#   'resolved_title': "Apprendre l'anglais en ligne",
#   'resolved_url': 'https://fr.appewa.com/reader/bb12496e-ebdf-4045-8fad-a3959d0353c7/article',
#   'excerpt': "Apprendre l'anglais en ligne",
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '4',
#   'lang': 'fr',
#   'listen_duration_estimate': 2},
#  {'item_id': '2907070551',
#   'resolved_id': '0',
#   'given_url': 'http://www.public.asu.edu/~hnesse/classes/seir.html',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1584877059',
#   'time_updated': '1584877071',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 9,
#   'resolved_title': '',
#   'resolved_url': '',
#   'excerpt': '',
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '0',
#   'lang': '',
#   'tags': {'corona': {'item_id': '2907070551', 'tag': 'corona'}},
#   'listen_duration_estimate': 0},
#  {'item_id': '2904803751',
#   'resolved_id': '2904803751',
#   'given_url': 'https://www.google.com/search?sxsrf=ALeKk03eeW7ZJNfvGrM6uMfFI7ukBNIBtA:1583257365212&q=les+freres+asniere+sur+seine&spell=1&sa=X&ved=2ahUKEwirrd2m7f7nAhVwD2MBHdqVBpcQBSgAegQIDBAq&biw=1440&bih=820&dpr=2',
#   'given_title': 'les freres asniere sur seine - Recherche Google',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1583336418',
#   'time_updated': '1583336421',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 10,
#   'resolved_title': 'les freres asniere sur seine',
#   'resolved_url': 'https://www.google.com/search?sxsrf=ALeKk03eeW7ZJNfvGrM6uMfFI7ukBNIBtA:1583257365212&q=les+freres+asniere+sur+seine&spell=1&sa=X&ved=2ahUKEwirrd2m7f7nAhVwD2MBHdqVBpcQBSgAegQIDBAq&biw=1440&bih=820&dpr=2',
#   'excerpt': "Association Quartier des 3 Frères à Asnières sur Seine, Asnières, Ile-De-France, France. 180 J'aime. Nous sommes l'Association qui regroupe les habitants...",
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '19',
#   'lang': 'en',
#   'domain_metadata': {'name': 'Google',
#    'logo': 'https://logo.clearbit.com/google.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/google.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 7},
#  {'item_id': '890289939',
#   'resolved_id': '890289939',
#   'given_url': 'https://cloudinary.com/documentation/django_integration',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577899037',
#   'time_updated': '1577899049',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 11,
#   'resolved_title': 'Django integration',
#   'resolved_url': 'http://cloudinary.com/documentation/django_integration',
#   'excerpt': 'Cloudinary is a cloud-based service that provides an end-to-end image management solution including uploads, storage, manipulations, optimizations and delivery.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '1191',
#   'lang': 'en',
#   'time_to_read': 5,
#   'tags': {'django': {'item_id': '890289939', 'tag': 'django'}},
#   'image': {'item_id': '890289939',
#    'src': 'http://res.cloudinary.com/demo/image/upload/w_150,h_150,c_thumb,g_face,r_20,e_sepia/l_cloudinary_icon,g_south_east,x_5,y_5,w_50,o_60,e_brightness:200/a_10/front_face.png',
#    'width': '174',
#    'height': '174'},
#   'images': {'1': {'item_id': '890289939',
#     'image_id': '1',
#     'src': 'http://res.cloudinary.com/demo/image/upload/w_150,h_150,c_thumb,g_face,r_20,e_sepia/l_cloudinary_icon,g_south_east,x_5,y_5,w_50,o_60,e_brightness:200/a_10/front_face.png',
#     'width': '174',
#     'height': '174',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '890289939',
#     'image_id': '2',
#     'src': 'http://res.cloudinary.com/demo/image/upload/w_250,h_168,c_fit/sample.jpg',
#     'width': '250',
#     'height': '168',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '890289939',
#     'image_id': '3',
#     'src': 'http://res.cloudinary.com/demo/image/upload/w_100,h_150,c_fill/sample.jpg',
#     'width': '100',
#     'height': '150',
#     'credit': '',
#     'caption': ''},
#    '4': {'item_id': '890289939',
#     'image_id': '4',
#     'src': 'http://res.cloudinary.com/demo/image/facebook/w_90,h_98,c_fill,g_face,r_max,e_sepia/billclinton.jpg',
#     'width': '90',
#     'height': '98',
#     'credit': '',
#     'caption': ''}},
#   'listen_duration_estimate': 461},
#  {'item_id': '2839695377',
#   'resolved_id': '144877147',
#   'given_url': 'https://github.com/andrewebdev/django-video/blob/master/setup.py',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898878',
#   'time_updated': '1577898905',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 12,
#   'resolved_title': 'andrewebdev/django-video',
#   'resolved_url': 'https://github.com/andrewebdev/django-video',
#   'excerpt': '© Copyright 2009 Andre Engelbrecht. All Rights Reserved.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '266',
#   'lang': 'en',
#   'top_image_url': 'https://avatars3.githubusercontent.com/u/84479?s=400&v=4',
#   'tags': {'django': {'item_id': '2839695377', 'tag': 'django'},
#    'streaming': {'item_id': '2839695377', 'tag': 'streaming'}},
#   'domain_metadata': {'name': 'GitHub',
#    'logo': 'https://logo.clearbit.com/github.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/github.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 103},
#  {'item_id': '1484325448',
#   'resolved_id': '1484325448',
#   'given_url': 'https://smerity.com/articles/2016/google_nmt_arch.html',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898801',
#   'time_updated': '1577898802',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 13,
#   'resolved_title': "Peeking into the neural network architecture used for Google's Neural Machine Translation",
#   'resolved_url': 'http://smerity.com/articles/2016/google_nmt_arch.html',
#   'excerpt': "The Google Neural Machine Translation paper (GNMT) describes an interesting approach towards deep learning in production. The paper and architecture are non-standard, in many cases deviating far from what you might expect from an architecture you'd find in an academic paper.",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '2843',
#   'lang': 'en',
#   'time_to_read': 13,
#   'top_image_url': 'http://smerity.com/media/images/articles/2016/gnmt_final_architecture.png',
#   'image': {'item_id': '1484325448',
#    'src': 'http://smerity.com/media/images/articles/2016/gnmt_arch_1_enc_dec.svg',
#    'width': '0',
#    'height': '0'},
#   'images': {'1': {'item_id': '1484325448',
#     'image_id': '1',
#     'src': 'http://smerity.com/media/images/articles/2016/gnmt_arch_1_enc_dec.svg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '1484325448',
#     'image_id': '2',
#     'src': 'http://smerity.com/media/images/articles/2016/bahdanau_no_attn.png',
#     'width': '50',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '1484325448',
#     'image_id': '3',
#     'src': 'http://smerity.com/media/images/articles/2016/gnmt_arch_attn.svg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '4': {'item_id': '1484325448',
#     'image_id': '4',
#     'src': 'http://smerity.com/media/images/articles/2016/bahdanau_attn.png',
#     'width': '70',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '5': {'item_id': '1484325448',
#     'image_id': '5',
#     'src': 'http://smerity.com/media/images/articles/2016/gnmt_arch_1_birnn.svg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '6': {'item_id': '1484325448',
#     'image_id': '6',
#     'src': 'http://smerity.com/media/images/articles/2016/gnmt_arch_deep_partial.svg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '7': {'item_id': '1484325448',
#     'image_id': '7',
#     'src': 'http://smerity.com/media/images/articles/2016/gnmt_arch_res.svg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '8': {'item_id': '1484325448',
#     'image_id': '8',
#     'src': 'http://smerity.com/media/images/articles/2016/gnmt_arch_deep_residuals.svg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''}},
#   'listen_duration_estimate': 1101},
#  {'item_id': '2390149666',
#   'resolved_id': '2390149666',
#   'given_url': 'https://towardsdatascience.com/nlp-sequence-to-sequence-networks-part-2-seq2seq-model-encoderdecoder-model-6c22e29fd7e1',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898774',
#   'time_updated': '1577898774',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 14,
#   'resolved_title': 'NLP | Sequence to Sequence Networks| Part 2|Seq2seq Model (EncoderDecoder Model)',
#   'resolved_url': 'https://towardsdatascience.com/nlp-sequence-to-sequence-networks-part-2-seq2seq-model-encoderdecoder-model-6c22e29fd7e1',
#   'excerpt': 'In [NLP | Sequence to Sequence Networks| Part 1| Processing text data] we learnt how to process text data, In this part we will create the model which will take the data we processed and use it to train to translate English sentences to French.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '1',
#   'has_image': '1',
#   'word_count': '831',
#   'lang': 'en',
#   'time_to_read': 4,
#   'top_image_url': 'https://cdn-images-1.medium.com/max/1200/1*_Nb5AADlqVQJDa0YyNFKGA.jpeg',
#   'authors': {'96490310': {'item_id': '2390149666',
#     'author_id': '96490310',
#     'name': "Mohammed Ma'amari",
#     'url': 'https://towardsdatascience.com/@mamarih1'}},
#   'image': {'item_id': '2390149666',
#    'src': 'https://cdn-images-1.medium.com/max/2000/1*_Nb5AADlqVQJDa0YyNFKGA.jpeg',
#    'width': '0',
#    'height': '0'},
#   'images': {'1': {'item_id': '2390149666',
#     'image_id': '1',
#     'src': 'https://cdn-images-1.medium.com/max/2000/1*_Nb5AADlqVQJDa0YyNFKGA.jpeg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '2390149666',
#     'image_id': '2',
#     'src': 'https://cdn-images-1.medium.com/max/1600/0*BpmYIit1tmLKlpDm.png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': 'Encoder Decoder Architecture'},
#    '3': {'item_id': '2390149666',
#     'image_id': '3',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*3lj8AGqfwEE5KCTJ-dXTvg.png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': 'Simple Representation'},
#    '4': {'item_id': '2390149666',
#     'image_id': '4',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*sO-SP58T4brE9EHazHSeGA.png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': 'Generative Model\xa0Chatbots'},
#    '5': {'item_id': '2390149666',
#     'image_id': '5',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*3pH2NH_8i7QMxpV0TFOdxw.jpeg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '6': {'item_id': '2390149666',
#     'image_id': '6',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*sDlV9_-PXBlt8jol-7Xjhg.jpeg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '7': {'item_id': '2390149666',
#     'image_id': '7',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*SMZbHBbXyhhpneqjRqlg6g.png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': 'Model Summary'}},
#   'videos': {'1': {'item_id': '2390149666',
#     'video_id': '1',
#     'src': 'https://towardsdatascience.com/media/85a65caff939525cf0ae85a19bb6caeb?postId=6c22e29fd7e1',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '2': {'item_id': '2390149666',
#     'video_id': '2',
#     'src': 'https://towardsdatascience.com/media/3539fbda2f4e49698e98378ad49ac1d9?postId=6c22e29fd7e1',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '3': {'item_id': '2390149666',
#     'video_id': '3',
#     'src': 'https://towardsdatascience.com/media/eeeb1f24b4fd1cc75752a0422a29c7d1?postId=6c22e29fd7e1',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '4': {'item_id': '2390149666',
#     'video_id': '4',
#     'src': 'https://towardsdatascience.com/media/915b751c02a59a4e5bdd673b22ea07b8?postId=6c22e29fd7e1',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '5': {'item_id': '2390149666',
#     'video_id': '5',
#     'src': 'https://towardsdatascience.com/media/cda3f5fa83e33509a4915993d5d4ef9d?postId=6c22e29fd7e1',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'}},
#   'domain_metadata': {'name': 'Towards Data Science',
#    'logo': 'https://logo.clearbit.com/towardsdatascience.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/towardsdatascience.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 322},
#  {'item_id': '2382199111',
#   'resolved_id': '2382199111',
#   'given_url': 'https://towardsdatascience.com/nlp-sequence-to-sequence-networks-part-1-processing-text-data-d141a5643b72',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898747',
#   'time_updated': '1577898756',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 15,
#   'resolved_title': 'NLP | Sequence to Sequence Networks| Part 1| Processing text\xa0data',
#   'resolved_url': 'https://towardsdatascience.com/nlp-sequence-to-sequence-networks-part-1-processing-text-data-d141a5643b72',
#   'excerpt': 'There are many benefits you can get by understanding NLP, you can make your own model to answer questions and use it in a chat bot, or you can make a translator to translate a text from your language to English language or the opposite, or maybe you make a text summarizer.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '1',
#   'has_image': '1',
#   'word_count': '736',
#   'lang': 'en',
#   'time_to_read': 3,
#   'top_image_url': 'https://cdn-images-1.medium.com/max/1200/1*_Nb5AADlqVQJDa0YyNFKGA.jpeg',
#   'tags': {'nlp': {'item_id': '2382199111', 'tag': 'nlp'}},
#   'authors': {'96490310': {'item_id': '2382199111',
#     'author_id': '96490310',
#     'name': "Mohammed Ma'amari",
#     'url': 'https://towardsdatascience.com/@mamarih1'}},
#   'image': {'item_id': '2382199111',
#    'src': 'https://cdn-images-1.medium.com/max/2600/1*_Nb5AADlqVQJDa0YyNFKGA.jpeg',
#    'width': '0',
#    'height': '0'},
#   'images': {'1': {'item_id': '2382199111',
#     'image_id': '1',
#     'src': 'https://cdn-images-1.medium.com/max/2600/1*_Nb5AADlqVQJDa0YyNFKGA.jpeg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': "Mohammed Ma'amariBlockedUnblockFollowFollowingNov 8, 2018"},
#    '2': {'item_id': '2382199111',
#     'image_id': '2',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*3dJqwlv2TyKvMib0_Lpuww.jpeg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '2382199111',
#     'image_id': '3',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*clOGgaE0nxsJAeJ2kM_hTQ.jpeg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '4': {'item_id': '2382199111',
#     'image_id': '4',
#     'src': 'https://cdn-images-1.medium.com/max/1600/1*HRbEaatZ95qs-nlgvr_dXw.jpeg',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''}},
#   'videos': {'1': {'item_id': '2382199111',
#     'video_id': '1',
#     'src': 'https://towardsdatascience.com/media/3c64eee18a020e9bc18389d6145cabc0?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '2': {'item_id': '2382199111',
#     'video_id': '2',
#     'src': 'https://towardsdatascience.com/media/1d596b20341f2047cd2499c4d8520bb3?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '3': {'item_id': '2382199111',
#     'video_id': '3',
#     'src': 'https://towardsdatascience.com/media/9d9f8faf466ab1c5fa4c6ff4e3b3a1fc?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '4': {'item_id': '2382199111',
#     'video_id': '4',
#     'src': 'https://towardsdatascience.com/media/63a15cc8eaa216479ec463cc35fc2157?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '5': {'item_id': '2382199111',
#     'video_id': '5',
#     'src': 'https://towardsdatascience.com/media/774b71958e210925c3b98e420989ff7c?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '6': {'item_id': '2382199111',
#     'video_id': '6',
#     'src': 'https://towardsdatascience.com/media/aae4dfbcab38aa7f6a974594e0d47a9a?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '7': {'item_id': '2382199111',
#     'video_id': '7',
#     'src': 'https://towardsdatascience.com/media/b921f083d311ee11bc33a80ef4ef81f6?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '8': {'item_id': '2382199111',
#     'video_id': '8',
#     'src': 'https://towardsdatascience.com/media/2c1b2913045f327c1ba309ec62c68fc1?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '9': {'item_id': '2382199111',
#     'video_id': '9',
#     'src': 'https://towardsdatascience.com/media/6c85b534d3ea9e6934a4b380051e5920?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'},
#    '10': {'item_id': '2382199111',
#     'video_id': '10',
#     'src': 'https://towardsdatascience.com/media/acc3c090e8e316e07da561e904473504?postId=d141a5643b72',
#     'width': '700',
#     'height': '250',
#     'type': '7',
#     'vid': '',
#     'length': '0'}},
#   'domain_metadata': {'name': 'Towards Data Science',
#    'logo': 'https://logo.clearbit.com/towardsdatascience.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/towardsdatascience.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 285},
#  {'item_id': '174173301',
#   'resolved_id': '174173301',
#   'given_url': 'https://fr.wikipedia.org/wiki/Conjonction_(grammaire)',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898727',
#   'time_updated': '1577898728',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 16,
#   'resolved_title': 'Conjonction (grammaire)',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/Conjonction_(grammaire)',
#   'excerpt': 'En grammaire traditionnelle, une conjonction est un mot invariable qui sert à interconnecter deux mots, groupes de mots ou propositions, en exprimant une relation grammaticale, sémantique et logique entre les entités reliées.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '3326',
#   'lang': 'fr',
#   'time_to_read': 17,
#   'authors': {'125921901': {'item_id': '174173301',
#     'author_id': '125921901',
#     'name': 'conjuncționalizare',
#     'url': 'https://dexonline.ro/definitie-dtl/conjunc%C8%9Bionaliz%C3%A1re'}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 1287},
#  {'item_id': '2400166532',
#   'resolved_id': '2400166532',
#   'given_url': 'https://www.ekino.com/articles/handson-de-quelques-taches-courantes-en-nlp',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898526',
#   'time_updated': '1577898538',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 17,
#   'resolved_title': 'Handson de quelques tâches courantes en NLP',
#   'resolved_url': 'https://www.ekino.com/articles/handson-de-quelques-taches-courantes-en-nlp',
#   'excerpt': 'This post is also available in english. Dans ce post, nous allons dérouler quelques exemples de tâches courantes en Natural Language Processing (NLP), en mettant en parallèle deux librairies Python (en) couramment utilisées : NLTK (en) et SpaCy (en).',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '2698',
#   'lang': 'fr',
#   'time_to_read': 13,
#   'top_image_url': 'https://images.ctfassets.net/95wnqgvmhlea/3eM3mJ7BdCSq6OW0y2qiIo/c83970dc36c36bb9e94cee30a0a218aa/15891138064_51f8766cb8_z.jpg?fm=jpg',
#   'tags': {'nlp': {'item_id': '2400166532', 'tag': 'nlp'}},
#   'authors': {'100214772': {'item_id': '2400166532',
#     'author_id': '100214772',
#     'name': 'Pauline Olivier',
#     'url': 'https://www.ekino.com/author/pauline-olivier'}},
#   'image': {'item_id': '2400166532',
#    'src': 'https://images.ctfassets.net/95wnqgvmhlea/3FQn5usy88UciWyAUMSaYm/87f854467cb4898520dcaac3ba754b9d/pytho3.png?fm=png',
#    'width': '0',
#    'height': '0'},
#   'images': {'1': {'item_id': '2400166532',
#     'image_id': '1',
#     'src': 'https://images.ctfassets.net/95wnqgvmhlea/3FQn5usy88UciWyAUMSaYm/87f854467cb4898520dcaac3ba754b9d/pytho3.png?fm=png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '2400166532',
#     'image_id': '2',
#     'src': 'https://images.ctfassets.net/95wnqgvmhlea/6EePj2ewEwQWKI2McqQAAA/e402255fa8702c9eb831c99a6e9548dc/cell.png?fm=png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '2400166532',
#     'image_id': '3',
#     'src': 'https://images.ctfassets.net/95wnqgvmhlea/2lffMyV2ccEuI2cMkqyigs/367f93360c80948ae3e208662724e14a/run.png?fm=png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '4': {'item_id': '2400166532',
#     'image_id': '4',
#     'src': 'https://images.ctfassets.net/95wnqgvmhlea/16Zg0grijueCse6OSKQ0Ok/2d5bdba09b76e9c91d26927a396fb4d5/nltk_tag.png?fm=png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''},
#    '5': {'item_id': '2400166532',
#     'image_id': '5',
#     'src': 'https://images.ctfassets.net/95wnqgvmhlea/6IiJuGuXugmY6eQyei2e8y/bf2818d4f090fa128893fefef6cf284c/spacy_tag.png?fm=png',
#     'width': '0',
#     'height': '0',
#     'credit': '',
#     'caption': ''}},
#   'listen_duration_estimate': 1044},
#  {'item_id': '2839690226',
#   'resolved_id': '2839690226',
#   'given_url': 'https://fr.wikipedia.org/wiki/SpaCy',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898456',
#   'time_updated': '1577898466',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 18,
#   'resolved_title': 'SpaCy',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/SpaCy',
#   'excerpt': "En pratique\xa0: Quelles sources sont attendues\xa0? Comment ajouter mes sources\xa0? SpaCy est une bibliothèque logicielle Python de traitement automatique des langues développée par Matt Honnibal de l'entreprise Explosion AI[2].",
#   'is_article': '1',
#   'is_index': '1',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '195',
#   'lang': 'fr',
#   'top_image_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/88/SpaCy_logo.svg/1200px-SpaCy_logo.svg.png',
#   'tags': {'nlp': {'item_id': '2839690226', 'tag': 'nlp'}},
#   'image': {'item_id': '2839690226',
#    'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/88/SpaCy_logo.svg/220px-SpaCy_logo.svg.png',
#    'width': '220',
#    'height': '79'},
#   'images': {'1': {'item_id': '2839690226',
#     'image_id': '1',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/88/SpaCy_logo.svg/220px-SpaCy_logo.svg.png',
#     'width': '220',
#     'height': '79',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '2839690226',
#     'image_id': '2',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a1/2017-fr.wp-orange-source.svg/45px-2017-fr.wp-orange-source.svg.png',
#     'width': '45',
#     'height': '45',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '2839690226',
#     'image_id': '3',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Nuvola_apps_emacs.png/24px-Nuvola_apps_emacs.png',
#     'width': '24',
#     'height': '24',
#     'credit': '',
#     'caption': ''},
#    '4': {'item_id': '2839690226',
#     'image_id': '4',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Logo_proba_4.svg/31px-Logo_proba_4.svg.png',
#     'width': '31',
#     'height': '24',
#     'credit': '',
#     'caption': ''}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 75},
#  {'item_id': '60275390',
#   'resolved_id': '60275390',
#   'given_url': 'https://fr.wikipedia.org/wiki/Scala_(langage)',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577898320',
#   'time_updated': '1577898320',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 19,
#   'resolved_title': 'Scala (langage)',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/Scala_(langage)',
#   'excerpt': "Scala est un langage de programmation multi-paradigme conçu à l'École polytechnique fédérale de Lausanne (EPFL) pour exprimer les modèles de programmation courants dans une forme concise et élégante.",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '686',
#   'lang': 'fr',
#   'time_to_read': 3,
#   'image': {'item_id': '60275390',
#    'src': 'https://fr.wikipedia.org/wiki/Fichier:Scala.png',
#    'width': '131',
#    'height': '37'},
#   'images': {'1': {'item_id': '60275390',
#     'image_id': '1',
#     'src': 'https://fr.wikipedia.org/wiki/Fichier:Scala.png',
#     'width': '131',
#     'height': '37',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '60275390',
#     'image_id': '2',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/cc/Circle-icons-dev.svg/24px-Circle-icons-dev.svg.png',
#     'width': '24',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail de la programmation informatique'}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 266},
#  {'item_id': '2690910611',
#   'resolved_id': '2690910611',
#   'given_url': 'http://mobile.interieur.gouv.fr/Actualites/L-actu-du-Ministere/Alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577897973',
#   'time_updated': '1577897974',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 20,
#   'resolved_title': 'Alicem, la première solution d’identité numérique régalienne sécurisée',
#   'resolved_url': 'https://mobile.interieur.gouv.fr/Actualites/L-actu-du-Ministere/Alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee',
#   'excerpt': "Alicem est une application pour smartphone développée par le ministère de l’Intérieur et l’Agence nationale des titres sécurisés (ANTS) qui permet à tout particulier, qui décide de l'utiliser, de prouver son identité sur Internet de manière sécurisée.",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '638',
#   'lang': 'fr',
#   'time_to_read': 3,
#   'top_image_url': 'http://mobile.interieur.gouv.fr/var/miomcti/storage/images/www.interieur.gouv.fr/version-fre/actualites/l-actu-du-ministere/alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee/936936-1-fre-FR/Alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee.jpg',
#   'authors': {'1214917': {'item_id': '2690910611',
#     'author_id': '1214917',
#     'name': "Ministère de l'Intérieur",
#     'url': ''}},
#   'image': {'item_id': '2690910611',
#    'src': 'https://mobile.interieur.gouv.fr/var/miomcti/storage/images/www.interieur.gouv.fr/version-fre/actualites/l-actu-du-ministere/alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee/936936-1-fre-FR/Alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee_catcher.jpg',
#    'width': '452',
#    'height': '212'},
#   'images': {'1': {'item_id': '2690910611',
#     'image_id': '1',
#     'src': 'https://mobile.interieur.gouv.fr/var/miomcti/storage/images/www.interieur.gouv.fr/version-fre/actualites/l-actu-du-ministere/alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee/936936-1-fre-FR/Alicem-la-premiere-solution-d-identite-numerique-regalienne-securisee_catcher.jpg',
#     'width': '452',
#     'height': '212',
#     'credit': '',
#     'caption': ''}},
#   'listen_duration_estimate': 247},
#  {'item_id': '1384026401',
#   'resolved_id': '1384026401',
#   'given_url': 'https://stackabuse.com/reading-and-writing-json-to-a-file-in-python/',
#   'given_title': '',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1577897919',
#   'time_updated': '1577897919',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 21,
#   'resolved_title': 'Reading and Writing JSON to a File in Python',
#   'resolved_url': 'https://stackabuse.com/reading-and-writing-json-to-a-file-in-python/',
#   'excerpt': "Over the last 5-10 years, the JSON format has been one of, if not the most, popular ways to serialize data. Especially in the web development world, you'll likely encounter JSON through one of the many REST APIs, application configuration, or even simple data storage.",
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '1037',
#   'lang': 'en',
#   'time_to_read': 5,
#   'authors': {'2526517': {'item_id': '1384026401',
#     'author_id': '2526517',
#     'name': 'Scott Robinson',
#     'url': ''}},
#   'listen_duration_estimate': 401},
#  {'item_id': '91274609',
#   'resolved_id': '91274609',
#   'given_url': 'https://fr.wikipedia.org/wiki/Comet_(informatique)',
#   'given_title': 'Comet (informatique) — Wikipédia',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1576930551',
#   'time_updated': '1576930564',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 22,
#   'resolved_title': 'Comet (informatique)',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/Comet_(informatique)',
#   'excerpt': "Vous pouvez partager vos connaissances en l’améliorant (comment\xa0?) selon les recommandations des projets correspondants. Comet est une nouvelle approche permettant à un serveur web d'envoyer des informations au navigateur web sans que celui-ci l'ait explicitement demandé.",
# ...
#   'resolved_url': 'https://www.youtube.com/watch?v=NCqjCQdYgRk',
#   'excerpt': 'Leonard Zelig es un sujeto de origen judío que posee una asombrosa habilidad: puede transformarse en quien quiera. A partir del contacto con otros, este hombre es capaz de tomar parte de los atributos ajenos y hacerlos propios, convirtiéndose así en una suerte de camaleón humano. Ante semejante',
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '2',
#   'has_image': '1',
#   'word_count': '0',
#   'lang': 'es',
#   'tags': {'before the flood': {'item_id': '2075605116',
#     'tag': 'before the flood'},
#    'documentary': {'item_id': '2075605116', 'tag': 'documentary'}},
#   'image': {'item_id': '2075605116',
#    'src': 'http://img.youtube.com/vi/NCqjCQdYgRk/maxresdefault.jpg',
#    'width': '480',
#    'height': '360'},
#   'images': {'1': {'item_id': '2075605116',
#     'image_id': '1',
#     'src': 'http://img.youtube.com/vi/NCqjCQdYgRk/maxresdefault.jpg',
#     'width': '480',
#     'height': '360',
#     'credit': '',
#     'caption': ''}},
#   'videos': {'1': {'item_id': '2075605116',
#     'video_id': '1',
#     'src': 'http://www.youtube.com/watch?v=NCqjCQdYgRk',
#     'width': '0',
#     'height': '0',
#     'type': '1',
#     'vid': 'NCqjCQdYgRk',
#     'length': '343'}},
#   'domain_metadata': {'name': 'YouTube',
#    'logo': 'https://logo.clearbit.com/youtube.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/youtube.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 0},
#  {'item_id': '335239985',
#   'resolved_id': '335239985',
#   'given_url': 'https://fr.wikipedia.org/wiki/Robert_Crumb',
#   'given_title': 'Robert Crumb — Wikipédia',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1518781561',
#   'time_updated': '1554628225',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 117,
#   'resolved_title': 'Robert Crumb',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/Robert_Crumb',
#   'excerpt': 'Robert Crumb est un auteur de bande dessinée américain, et un musicien compositeur, né à Philadelphie le 30 août 1943.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '3264',
#   'lang': 'fr',
#   'time_to_read': 16,
#   'top_image_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/55/Robert_Crumb%2C_2014_%28cropped%29.JPG/1200px-Robert_Crumb%2C_2014_%28cropped%29.JPG',
#   'tags': {'before the flood': {'item_id': '335239985',
#     'tag': 'before the flood'},
#    'documentary': {'item_id': '335239985', 'tag': 'documentary'}},
#   'authors': {'5937251': {'item_id': '335239985',
#     'author_id': '5937251',
#     'name': 'Comics Code Authority',
#     'url': 'https://fr.wikipedia.org/wiki/Comics_Code_Authority'}},
#   'image': {'item_id': '335239985',
#    'src': 'https://fr.wikipedia.org/wiki/Fichier:Robert_Crumb,_2014_(cropped).JPG',
#    'width': '220',
#    'height': '311'},
#   'images': {'1': {'item_id': '335239985',
#     'image_id': '1',
#     'src': 'https://fr.wikipedia.org/wiki/Fichier:Robert_Crumb,_2014_(cropped).JPG',
#     'width': '220',
#     'height': '311',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '335239985',
#     'image_id': '2',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/03/Flag_of_Italy.svg/20px-Flag_of_Italy.svg.png',
#     'width': '20',
#     'height': '13',
#     'credit': '',
#     'caption': ''},
#    '3': {'item_id': '335239985',
#     'image_id': '3',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Flag_of_Sweden.svg/20px-Flag_of_Sweden.svg.png',
#     'width': '20',
#     'height': '13',
#     'credit': '',
#     'caption': ''},
#    '4': {'item_id': '335239985',
#     'image_id': '4',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/20px-Flag_of_France.svg.png',
#     'width': '20',
#     'height': '13',
#     'credit': '',
#     'caption': ''},
#    '5': {'item_id': '335239985',
#     'image_id': '5',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Flag_of_Spain.svg/20px-Flag_of_Spain.svg.png',
#     'width': '20',
#     'height': '13',
#     'credit': '',
#     'caption': ''},
#    '6': {'item_id': '335239985',
#     'image_id': '6',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/5f/WBDbulle2.svg/25px-WBDbulle2.svg.png',
#     'width': '25',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail de la bande dessinée'},
#    '7': {'item_id': '335239985',
#     'image_id': '7',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/1f/AnarchySymbolInk.svg/23px-AnarchySymbolInk.svg.png',
#     'width': '23',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail de l’anarchisme'},
#    '8': {'item_id': '335239985',
#     'image_id': '8',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png',
#     'width': '46',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail des États-Unis'}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 1263},
#  {'item_id': '323301344',
#   'resolved_id': '323301344',
#   'given_url': 'https://fr.wikipedia.org/wiki/Lou_Reed',
#   'given_title': 'Lou Reed — Wikipédia',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1518781545',
#   'time_updated': '1554628194',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 118,
#   'resolved_title': 'Lou Reed',
#   'resolved_url': 'https://fr.wikipedia.org/wiki/Lou_Reed',
#   'excerpt': 'Lou Reed (2 mars 1942 à Brooklyn, New York - 27 octobre 2013 à Southampton, Long Island, New York) est un auteur-compositeur-interprète américain qui a commencé sa carrière avec le groupe The Velvet Underground.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '3354',
#   'lang': 'fr',
#   'time_to_read': 17,
#   'top_image_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Lou_Reed_%285900962918%29.jpg/1200px-Lou_Reed_%285900962918%29.jpg',
#   'tags': {'before the flood': {'item_id': '323301344',
#     'tag': 'before the flood'},
#    'documentary': {'item_id': '323301344', 'tag': 'documentary'}},
#   'authors': {'218929': {'item_id': '323301344',
#     'author_id': '218929',
#     'name': 'Andy Warhol',
#     'url': ''}},
#   'image': {'item_id': '323301344',
#    'src': 'https://fr.wikipedia.org/wiki/Fichier:Lou_Reed_(5900962918).jpg',
#    'width': '220',
#    'height': '173'},
#   'images': {'1': {'item_id': '323301344',
#     'image_id': '1',
#     'src': 'https://fr.wikipedia.org/wiki/Fichier:Lou_Reed_(5900962918).jpg',
#     'width': '220',
#     'height': '173',
#     'credit': '',
#     'caption': ''},
#    '2': {'item_id': '323301344',
#     'image_id': '2',
#     'src': 'https://fr.wikipedia.org/wiki/Fichier:Lou_Reed_HS_Yearbook_(cropped).jpg',
#     'width': '170',
#     'height': '195',
#     'credit': '',
#     'caption': 'Lou Reed en 1959'},
#    '3': {'item_id': '323301344',
#     'image_id': '3',
#     'src': 'https://fr.wikipedia.org/wiki/Fichier:Lou_Reed_1977.JPG',
#     'width': '170',
#     'height': '239',
#     'credit': '',
#     'caption': 'Lou Reed en 1977'},
#    '5': {'item_id': '323301344',
#     'image_id': '5',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/57/E-Guitare-horiz.png/48px-E-Guitare-horiz.png',
#     'width': '48',
#     'height': '19',
#     'credit': '',
#     'caption': 'Portail de la guitare'},
#    '6': {'item_id': '323301344',
#     'image_id': '6',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/ac/Musical_notes.svg/32px-Musical_notes.svg.png',
#     'width': '32',
#     'height': '24',
#     'credit': '',
#     'caption': 'Portail de la musique'},
#    '7': {'item_id': '323301344',
#     'image_id': '7',
#     'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Flag_of_New_York_City.svg/37px-Flag_of_New_York_City.svg.png',
#     'width': '37',
#     'height': '22',
#     'credit': '',
#     'caption': 'Portail de New York'}},
#   'domain_metadata': {'name': 'Wikipedia',
#    'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#   'listen_duration_estimate': 1298},
#  {'item_id': '9142472',
#   'resolved_id': '9142472',
#   'given_url': 'https://www.urbandictionary.com/define.php?term=fo%27%20shizzle%20my%20nizzle',
#   'given_title': "Urban Dictionary: fo' shizzle my nizzle",
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1518086610',
#   'time_updated': '1522744494',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 119,
#   'resolved_title': "fo' shizzle my nizzle",
#   'resolved_url': 'http://www.urbandictionary.com/define.php?term=fo%27%20shizzle%20my%20nizzle',
#   'excerpt': '',
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '1',
#   'has_image': '1',
#   'word_count': '0',
#   'lang': 'en',
#   'tags': {'darijadmerikan': {'item_id': '9142472', 'tag': 'darijadmerikan'},
#    'vocab': {'item_id': '9142472', 'tag': 'vocab'}},
#   'authors': {'6488759': {'item_id': '9142472',
#     'author_id': '6488759',
#     'name': 'anonymous',
#     'url': 'http://www.urbandictionary.com/author.php?author=anonymous'}},
#   'image': {'item_id': '9142472',
#    'src': 'http://img.youtube.com/vi/JPOZd-XMZeo/0.jpg',
#    'width': '480',
#    'height': '360'},
#   'images': {'1': {'item_id': '9142472',
#     'image_id': '1',
#     'src': 'http://img.youtube.com/vi/JPOZd-XMZeo/0.jpg',
#     'width': '480',
#     'height': '360',
#     'credit': '',
#     'caption': ''}},
#   'videos': {'1': {'item_id': '9142472',
#     'video_id': '1',
#     'src': 'http://www.youtube.com/embed/JPOZd-XMZeo?playlist=&showinfo=1&rel=0&wmode=transparent',
#     'width': '425',
#     'height': '349',
#     'type': '1',
#     'vid': 'JPOZd-XMZeo',
#     'length': '0'}},
#   'listen_duration_estimate': 0},
#  {'item_id': '2064210780',
#   'resolved_id': '2064210780',
#   'given_url': 'http://www.wordreference.com/enfr/go%20through',
#   'given_title': 'go through - English-French Dictionary WordReference.com',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1518086393',
#   'time_updated': '1518086423',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 120,
#   'resolved_title': '',
#   'resolved_url': 'http://www.wordreference.com/enfr/go%20through',
#   'excerpt': '',
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '0',
#   'lang': '',
#   'tags': {'english': {'item_id': '2064210780', 'tag': 'english'},
#    'vocab': {'item_id': '2064210780', 'tag': 'vocab'}},
#   'listen_duration_estimate': 0},
#  {'item_id': '2064210468',
#   'resolved_id': '2064210468',
#   'given_url': 'https://dictionary.cambridge.org/fr/dictionnaire/anglais/work-through-something',
#   'given_title': 'work through something définition dans le dictionnaire Anglais de Cambridge',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1518086368',
#   'time_updated': '1518086377',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 121,
#   'resolved_title': 'work through something définition dans le dictionnaire Anglais de Cambridge',
#   'resolved_url': 'https://dictionary.cambridge.org/fr/dictionnaire/anglais/work-through-something',
#   'excerpt': 'Définition anglaise de “work through something”                        (Definition of “work through something” from the Cambridge Academic Content Dictionary © Cambridge University Press)',
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '20',
#   'lang': 'en',
#   'amp_url': 'https://dictionary.cambridge.org/fr/amp/anglais/work-through-something',
#   'top_image_url': 'https://dictionary.cambridge.org/fr/external/images/CDO_logo_120x120.jpg?version=3.1.89',
#   'tags': {'english': {'item_id': '2064210468', 'tag': 'english'},
#    'vocab': {'item_id': '2064210468', 'tag': 'vocab'}},
#   'listen_duration_estimate': 8},
#  {'item_id': '2064207864',
#   'resolved_id': '2064207864',
#   'given_url': 'https://www.urbandictionary.com/define.php?term=sb.%20ain%27t%20got%20shit%20on%20me',
#   'given_title': "Urban Dictionary: sb. ain't got shit on me",
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1518086173',
#   'time_updated': '1518783749',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 122,
#   'resolved_title': "sb. ain't got shit on me",
#   'resolved_url': 'https://www.urbandictionary.com/define.php?term=sb.%20ain%27t%20got%20shit%20on%20me',
#   'excerpt': '',
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '0',
#   'lang': 'en',
#   'amp_url': 'https://www.urbandictionary.com/define.php?term=sb.%20ain%27t%20got%20shit%20on%20me&amp=true',
#   'tags': {'expression': {'item_id': '2064207864', 'tag': 'expression'},
#    'urban': {'item_id': '2064207864', 'tag': 'urban'},
#    'vocab': {'item_id': '2064207864', 'tag': 'vocab'}},
#   'authors': {'83719120': {'item_id': '2064207864',
#     'author_id': '83719120',
#     'name': 'C-Webb',
#     'url': 'https://www.urbandictionary.com/author.php?author=C-Webb'}},
#   'listen_duration_estimate': 0},
#  {'item_id': '2011690338',
#   'resolved_id': '2011690338',
#   'given_url': 'http://www.marrakech-cityguide.com/site-archeologique-de-aghmat-3187',
#   'given_title': 'Site archéologique de AGHMAT à 32 km de Marrakech',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1514897227',
#   'time_updated': '1514903673',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 123,
#   'resolved_title': 'Site archéologique de AGHMAT',
#   'resolved_url': 'http://www.marrakech-cityguide.com/site-archeologique-de-aghmat-3187',
#   'excerpt': 'Aghmat, est située à 32 km de Marrakech sur la route de l’Ourika, province de Al Haouz, c’est aussi une commune rurale locale créé en 1959.   La ville de Aghmat est considérée comme étant la plus ancienne ville marocaine, érigée même avant l’entrée de l’Islam au Maroc.',
#   'is_article': '1',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '1',
#   'word_count': '225',
#   'lang': 'fr',
#   'amp_url': 'http://www.marrakech-cityguide.com/site-archeologique-de-aghmat-3187/amp/',
#   'top_image_url': 'http://www.marrakech-cityguide.com/wp-content/uploads/IMG_1311.jpg',
#   'tags': {'archéologie': {'item_id': '2011690338', 'tag': 'archéologie'},
#    'marrakech': {'item_id': '2011690338', 'tag': 'marrakech'},
#    'voyage': {'item_id': '2011690338', 'tag': 'voyage'}},
#   'authors': {'49416574': {'item_id': '2011690338',
#     'author_id': '49416574',
#     'name': 'Pierre-Marie Coupry',
#     'url': 'http://www.marrakech-cityguide.com/author/pm-seo/'}},
#   'image': {'item_id': '2011690338',
#    'src': 'http://www.marrakech-cityguide.com/wp-content/uploads/IMG_1311-620x420.jpg',
#    'width': '620',
#    'height': '420'},
#   'images': {'1': {'item_id': '2011690338',
#     'image_id': '1',
#     'src': 'http://www.marrakech-cityguide.com/wp-content/uploads/IMG_1311-620x420.jpg',
#     'width': '620',
#     'height': '420',
#     'credit': '',
#     'caption': ''}},
#   'listen_duration_estimate': 87},
#  {'item_id': '2005265162',
#   'resolved_id': '2005265162',
#   'given_url': 'https://www.bizjournals.com/sanjose/news/2017/12/26/artificial-intelligence-talent-shortage-salaries.html',
#   'given_title': 'Artificial intelligence hindered by talent shortage, according to Ernst & Y',
#   'favorite': '0',
#   'status': '0',
#   'time_added': '1514851243',
#   'time_updated': '1514903757',
#   'time_read': '0',
#   'time_favorited': '0',
#   'sort_id': 124,
#   'resolved_title': '',
#   'resolved_url': 'https://www.bizjournals.com/sanjose/news/2017/12/26/artificial-intelligence-talent-shortage-salaries.html',
#   'excerpt': '',
#   'is_article': '0',
#   'is_index': '0',
#   'has_video': '0',
#   'has_image': '0',
#   'word_count': '0',
#   'lang': 'en',
#   'tags': {'artificial intelligence': {'item_id': '2005265162',
#     'tag': 'artificial intelligence'}},
#   'domain_metadata': {'name': 'The Business Journals',
#    'logo': 'https://logo.clearbit.com/bizjournals.com?size=800',
#    'greyscale_logo': 'https://logo.clearbit.com/bizjournals.com?size=800&greyscale=true'},
#   'listen_duration_estimate': 0}]

# %%
tags_list[0]
# Out:
# {'item_id': '698231177',
#  'resolved_id': '698231177',
#  'given_url': 'https://fr.wikipedia.org/wiki/SHRDLU',
#  'given_title': '',
#  'favorite': '0',
#  'status': '0',
#  'time_added': '1585673652',
#  'time_updated': '1585673660',
#  'time_read': '0',
#  'time_favorited': '0',
#  'sort_id': 0,
#  'resolved_title': 'SHRDLU',
#  'resolved_url': 'https://fr.wikipedia.org/wiki/SHRDLU',
#  'excerpt': 'SHRDLU a été l’un des premiers programmes informatiques de compréhension du langage naturel, développé par Terry Winograd au MIT à partir de 1968-1970. Il était écrit en Micro Planner et en Lisp et implémenté sur un ordinateur PDP-6 de DEC équipé d’un terminal graphique DEC.',
#  'is_article': '1',
#  'is_index': '1',
#  'has_video': '0',
#  'has_image': '1',
#  'word_count': '814',
#  'lang': 'fr',
#  'time_to_read': 4,
#  'top_image_url': 'https://upload.wikimedia.org/wikipedia/commons/b/bc/Shrdlu-original.jpg',
#  'tags': {'nlp': {'item_id': '698231177', 'tag': 'nlp'}},
#  'image': {'item_id': '698231177',
#   'src': 'https://fr.wikipedia.org/wiki/Fichier:Shrdlu-original.jpg',
#   'width': '220',
#   'height': '177'},
#  'images': {'1': {'item_id': '698231177',
#    'image_id': '1',
#    'src': 'https://fr.wikipedia.org/wiki/Fichier:Shrdlu-original.jpg',
#    'width': '220',
#    'height': '177',
#    'credit': '',
#    'caption': "Le logiciel présente un monde avec des blocs de différentes formes. L'utilisateur peut modifier le monde en donnant des instructions en langue naturelle."},
#   '2': {'item_id': '698231177',
#    'image_id': '2',
#    'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/02/Circle-icons-computer.svg/24px-Circle-icons-computer.svg.png',
#    'width': '24',
#    'height': '24',
#    'credit': '',
#    'caption': 'Portail de l’informatique'}},
#  'domain_metadata': {'name': 'Wikipedia',
#   'logo': 'https://logo.clearbit.com/wikipedia.org?size=800',
#   'greyscale_logo': 'https://logo.clearbit.com/wikipedia.org?size=800&greyscale=true'},
#  'listen_duration_estimate': 315}

# %%
data = pd.read_json(json.dumps(tags_list))
data
# Out:
#         item_id  resolved_id  \
# 0     698231177    698231177
# 1      12558068     12558068
# 2    2448904635   2448904635
# 3    2931905469   2931905469
# 4     443041106    443041106
# ..          ...          ...
# 120  2064210780   2064210780
# 121  2064210468   2064210468
# 122  2064207864   2064207864
# 123  2011690338   2011690338
# 124  2005265162   2005265162
#
#                                              given_url  \
# 0                 https://fr.wikipedia.org/wiki/SHRDLU
# 1    https://fr.wikipedia.org/wiki/Th%C3%A9orie_alg...
# 2    https://stackoverflow.com/questions/50236117/s...
# 3    https://towardsdatascience.com/15-python-libra...
# 4    https://fr.wikipedia.org/wiki/Dalvik_(machine_...
# ..                                                 ...
# 120     http://www.wordreference.com/enfr/go%20through
# 121  https://dictionary.cambridge.org/fr/dictionnai...
# 122  https://www.urbandictionary.com/define.php?ter...
# 123  http://www.marrakech-cityguide.com/site-archeo...
# 124  https://www.bizjournals.com/sanjose/news/2017/...
#
#                                            given_title  favorite  status  \
# 0                                                              0       0
# 1    Théorie algorithmique de l'information — Wikip...         0       0
# 2    python - Scraping: SSL: CERTIFICATE_VERIFY_FAI...         0       0
# 3                                                              0       0
# 4                                                              0       0
# ..                                                 ...       ...     ...
# 120  go through - English-French Dictionary WordRef...         0       0
# 121  work through something définition dans le dict...         0       0
# 122         Urban Dictionary: sb. ain't got shit on me         0       0
# 123  Site archéologique de AGHMAT à 32 km de Marrakech         0       0
# 124  Artificial intelligence hindered by talent sho...         0       0
#
#      time_added  time_updated  time_read  time_favorited  ...  time_to_read  \
# 0    1585673652    1585673660          0               0  ...           4.0
# 1    1585670987    1585670997          0               0  ...           3.0
# 2    1585646877    1585646885          0               0  ...           3.0
# 3    1585570363    1585672491          0               0  ...           9.0
# 4    1585152989    1585152990          0               0  ...           3.0
# ..          ...           ...        ...             ...  ...           ...
# 120  1518086393    1518086423          0               0  ...           NaN
# 121  1518086368    1518086377          0               0  ...           NaN
# 122  1518086173    1518783749          0               0  ...           NaN
# 123  1514897227    1514903673          0               0  ...           NaN
# 124  1514851243    1514903757          0               0  ...           NaN
#
#                                          top_image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1                                                  NaN
# 2    https://cdn.sstatic.net/Sites/stackoverflow/im...
# 3    https://miro.medium.com/max/1200/1*A4sZ2qS0jxV...
# 4                                                  NaN
# ..                                                 ...
# 120                                                NaN
# 121  https://dictionary.cambridge.org/fr/external/i...
# 122                                                NaN
# 123  http://www.marrakech-cityguide.com/wp-content/...
# 124                                                NaN
#
#                                                   tags  \
# 0      {'nlp': {'item_id': '698231177', 'tag': 'nlp'}}
# 1    {'théories': {'item_id': '12558068', 'tag': 't...
# 2    {'ssl: certificate_verify_f': {'item_id': '244...
# 3    {'data science': {'item_id': '2931905469', 'ta...
# 4                                                  NaN
# ..                                                 ...
# 120  {'english': {'item_id': '2064210780', 'tag': '...
# 121  {'english': {'item_id': '2064210468', 'tag': '...
# 122  {'expression': {'item_id': '2064207864', 'tag'...
# 123  {'archéologie': {'item_id': '2011690338', 'tag...
# 124  {'artificial intelligence': {'item_id': '20052...
#
#                                                  image  \
# 0    {'item_id': '698231177', 'src': 'https://fr.wi...
# 1    {'item_id': '12558068', 'src': 'https://upload...
# 2    {'item_id': '2448904635', 'src': 'https://grap...
# 3    {'item_id': '2931905469', 'src': 'https://miro...
# 4    {'item_id': '443041106', 'src': 'https://uploa...
# ..                                                 ...
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123  {'item_id': '2011690338', 'src': 'http://www.m...
# 124                                                NaN
#
#                                                 images  \
# 0    {'1': {'item_id': '698231177', 'image_id': '1'...
# 1    {'1': {'item_id': '12558068', 'image_id': '1',...
# 2    {'1': {'item_id': '2448904635', 'image_id': '1...
# 3    {'1': {'item_id': '2931905469', 'image_id': '1...
# 4    {'1': {'item_id': '443041106', 'image_id': '1'...
# ..                                                 ...
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123  {'1': {'item_id': '2011690338', 'image_id': '1...
# 124                                                NaN
#
#                                        domain_metadata  \
# 0    {'name': 'Wikipedia', 'logo': 'https://logo.cl...
# 1    {'name': 'Wikipedia', 'logo': 'https://logo.cl...
# 2    {'name': 'Stack Overflow', 'logo': 'https://lo...
# 3    {'name': 'Towards Data Science', 'logo': 'http...
# 4    {'name': 'Wikipedia', 'logo': 'https://logo.cl...
# ..                                                 ...
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124  {'name': 'The Business Journals', 'logo': 'htt...
#
#      listen_duration_estimate  \
# 0                         315
# 1                         224
# 2                         245
# 3                         795
# 4                         268
# ..                        ...
# 120                         0
# 121                         8
# 122                         0
# 123                        87
# 124                         0
#
#                                                authors  \
# 0                                                  NaN
# 1    {'3359036': {'item_id': '12558068', 'author_id...
# 2    {'37243038': {'item_id': '2448904635', 'author...
# 3    {'128552945': {'item_id': '2931905469', 'autho...
# 4                                                  NaN
# ..                                                 ...
# 120                                                NaN
# 121                                                NaN
# 122  {'83719120': {'item_id': '2064207864', 'author...
# 123  {'49416574': {'item_id': '2011690338', 'author...
# 124                                                NaN
#
#                                                amp_url videos
# 0                                                  NaN    NaN
# 1                                                  NaN    NaN
# 2                                                  NaN    NaN
# 3                                                  NaN    NaN
# 4                                                  NaN    NaN
# ..                                                 ...    ...
# 120                                                NaN    NaN
# 121  https://dictionary.cambridge.org/fr/amp/anglai...    NaN
# 122  https://www.urbandictionary.com/define.php?ter...    NaN
# 123  http://www.marrakech-cityguide.com/site-archeo...    NaN
# 124                                                NaN    NaN
#
# [125 rows x 30 columns]
